# %%
import pandas as pd

# %%
path = '/content/drive/MyDrive/Aviator/Odd_New.csv'
data = pd.read_csv(path)
data.head()
# Out:
#    Unnamed: 0     Odd  odd_entrada1  odd_entrada2  odd_entrada3  odd_entrada4  \
# 0           0    4.72          1.00          4.15          1.44          1.00
# 1           1    3.68          4.72          1.00          4.15          1.44
# 2           2  360.61          3.68          4.72          1.00          4.15
# 3           3    1.55        360.61          3.68          4.72          1.00
# 4           4    1.11          1.55        360.61          3.68          4.72
#
#    odd_entrada5  odd_entrada6  odd_entrada7  odd_entrada8  ...  \
# 0          1.00          1.62          1.63         24.34  ...
# 1          1.00          1.00          1.62          1.63  ...
# 2          1.44          1.00          1.00          1.62  ...
# 3          4.15          1.44          1.00          1.00  ...
# 4          1.00          4.15          1.44          1.00  ...
#
#    odd_entrada135  odd_entrada136  odd_entrada137  odd_entrada138  \
# 0            1.74            2.14            1.18            2.51
# 1            1.16            1.74            2.14            1.18
# 2            8.55            1.16            1.74            2.14
# 3            1.58            8.55            1.16            1.74
# 4            1.13            1.58            8.55            1.16
#
#    odd_entrada139  odd_entrada140  odd_entrada141  odd_entrada142  \
# 0            4.08            1.22            4.96           14.10
# 1            2.51            4.08            1.22            4.96
# 2            1.18            2.51            4.08            1.22
# 3            2.14            1.18            2.51            4.08
# 4            1.74            2.14            1.18            2.51
#
#    odd_entrada143  odd_entrada144
# 0            1.59           13.73
# 1           14.10            1.59
# 2            4.96           14.10
# 3            1.22            4.96
# 4            4.08            1.22
#
# [5 rows x 146 columns]

# %%
geral_cat = []
for name in data['Odd']:
  if name < 10:
    #print(name)
    if name < 5:
      if name < 3.5:
        if name < 2.6:
          if name < 2.1:
            if name < 1.7:
              if name < 1.45:
                if name < 1.3:
                  if name < 1.15:
                    if name < 1.05:
                      geral_cat.append(1)
                    else:
                      geral_cat.append(2)
                  else:
                    geral_cat.append(3)
                else:
                  geral_cat.append(4)
              else:
                geral_cat.append(5)
            else:
              geral_cat.append(6)
          else:
            geral_cat.append(7)
        else:
          geral_cat.append(8)
      else:
        geral_cat.append(9)
    else:
      geral_cat.append(10)
  else:
    geral_cat.append(11)

print(len(geral_cat))
# Crie uma coluna 'Odd_Categoria' com os valores inteiros calculados
data['Odd_Categoria1'] = geral_cat

# Remova as linhas com valores NaN em 'Odd_Categoria'
data = data.dropna(subset=['Odd_Categoria1'])

# Garanta que 'Odd_Categoria' seja do tipo inteiro
data['Odd_Categoria1'] = data['Odd_Categoria1'].astype(int)

# Verifique os valores únicos em 'Odd_Categoria'
unique_classes = data['Odd_Categoria1'].unique()
print(unique_classes)

data['Odd_Categoria1'].describe()
# Out:
# 999840
# [ 9 11  5  2  7  6  3  4 10  1  8]
# count    999840.000000
# mean          6.245491
# std           3.047597
# min           1.000000
# 25%           4.000000
# 50%           6.000000
# 75%           9.000000
# max          11.000000
# Name: Odd_Categoria1, dtype: float64

# %%
data1 = data
data = data[['Odd_Categoria1','odd_entrada1', 'odd_entrada2', 'odd_entrada3',
       'odd_entrada4', 'odd_entrada5', 'odd_entrada6', 'odd_entrada7',
       'odd_entrada8', 'odd_entrada9', 'odd_entrada10', 'odd_entrada11',
       'odd_entrada12', 'odd_entrada13', 'odd_entrada14', 'odd_entrada15',
       'odd_entrada16', 'odd_entrada17', 'odd_entrada18', 'odd_entrada19',
       'odd_entrada20', 'odd_entrada21', 'odd_entrada22', 'odd_entrada23',
       'odd_entrada24', 'odd_entrada25', 'odd_entrada26', 'odd_entrada27',
       'odd_entrada28', 'odd_entrada29', 'odd_entrada30', 'odd_entrada31',
       'odd_entrada32', 'odd_entrada33', 'odd_entrada34', 'odd_entrada35',
       'odd_entrada36', 'odd_entrada37', 'odd_entrada38', 'odd_entrada39',
       'odd_entrada40', 'odd_entrada41', 'odd_entrada42', 'odd_entrada43',
       'odd_entrada44', 'odd_entrada45', 'odd_entrada46', 'odd_entrada47',
       'odd_entrada48', 'odd_entrada49', 'odd_entrada50', 'odd_entrada51',
       'odd_entrada52', 'odd_entrada53', 'odd_entrada54', 'odd_entrada55',
       'odd_entrada56', 'odd_entrada57', 'odd_entrada58', 'odd_entrada59',
       'odd_entrada60', 'odd_entrada61', 'odd_entrada62', 'odd_entrada63',
       'odd_entrada64', 'odd_entrada65', 'odd_entrada66', 'odd_entrada67',
       'odd_entrada68', 'odd_entrada69', 'odd_entrada70', 'odd_entrada71',
       'odd_entrada72', 'odd_entrada73', 'odd_entrada74', 'odd_entrada75',
       'odd_entrada76', 'odd_entrada77', 'odd_entrada78', 'odd_entrada79',
       'odd_entrada80', 'odd_entrada81', 'odd_entrada82', 'odd_entrada83',
       'odd_entrada84', 'odd_entrada85', 'odd_entrada86', 'odd_entrada87',
       'odd_entrada88', 'odd_entrada89', 'odd_entrada90', 'odd_entrada91',
       'odd_entrada92', 'odd_entrada93', 'odd_entrada94', 'odd_entrada95',
       'odd_entrada96', 'odd_entrada97', 'odd_entrada98', 'odd_entrada99',
       'odd_entrada100', 'odd_entrada101', 'odd_entrada102', 'odd_entrada103',
       'odd_entrada104', 'odd_entrada105', 'odd_entrada106', 'odd_entrada107',
       'odd_entrada108', 'odd_entrada109', 'odd_entrada110', 'odd_entrada111',
       'odd_entrada112', 'odd_entrada113', 'odd_entrada114', 'odd_entrada115',
       'odd_entrada116', 'odd_entrada117', 'odd_entrada118', 'odd_entrada119',
       'odd_entrada120', 'odd_entrada121', 'odd_entrada122', 'odd_entrada123',
       'odd_entrada124', 'odd_entrada125', 'odd_entrada126', 'odd_entrada127',
       'odd_entrada128', 'odd_entrada129', 'odd_entrada130', 'odd_entrada131',
       'odd_entrada132', 'odd_entrada133', 'odd_entrada134', 'odd_entrada135',
       'odd_entrada136', 'odd_entrada137', 'odd_entrada138', 'odd_entrada139',
       'odd_entrada140', 'odd_entrada141', 'odd_entrada142', 'odd_entrada143',
       'odd_entrada144']]

# %%
data = data.tail(5000).reset_index(drop=True)
data.head()
# Out:
#    Odd_Categoria1  odd_entrada1  odd_entrada2  odd_entrada3  odd_entrada4  \
# 0               3          1.87          6.86          1.30          1.13
# 1              11          1.22          1.87          6.86          1.30
# 2               1         75.76          1.22          1.87          6.86
# 3              10          1.01         75.76          1.22          1.87
# 4              11          6.75          1.01         75.76          1.22
#
#    odd_entrada5  odd_entrada6  odd_entrada7  odd_entrada8  odd_entrada9  ...  \
# 0          4.93          1.62         20.00          2.32          1.02  ...
# 1          1.13          4.93          1.62         20.00          2.32  ...
# 2          1.30          1.13          4.93          1.62         20.00  ...
# 3          6.86          1.30          1.13          4.93          1.62  ...
# 4          1.87          6.86          1.30          1.13          4.93  ...
#
#    odd_entrada135  odd_entrada136  odd_entrada137  odd_entrada138  \
# 0           33.59            2.66            4.02            2.84
# 1            1.18           33.59            2.66            4.02
# 2            7.64            1.18           33.59            2.66
# 3            2.55            7.64            1.18           33.59
# 4            1.00            2.55            7.64            1.18
#
#    odd_entrada139  odd_entrada140  odd_entrada141  odd_entrada142  \
# 0            1.72            1.02            1.16            2.52
# 1            2.84            1.72            1.02            1.16
# 2            4.02            2.84            1.72            1.02
# 3            2.66            4.02            2.84            1.72
# 4           33.59            2.66            4.02            2.84
#
#    odd_entrada143  odd_entrada144
# 0            3.53            2.45
# 1            2.52            3.53
# 2            1.16            2.52
# 3            1.02            1.16
# 4            1.72            1.02
#
# [5 rows x 145 columns]

# %%
data.describe()
# Out:
#        Odd_Categoria1  odd_entrada1  odd_entrada2  odd_entrada3  odd_entrada4  \
# count     5000.000000   5000.000000   5000.000000   5000.000000   5000.000000
# mean         6.219000     21.602698     21.602270     21.602284     21.601478
# std          3.051639    770.490910    770.490917    770.490917    770.490936
# min          1.000000      1.000000      1.000000      1.000000      1.000000
# 25%          4.000000      1.300000      1.300000      1.300000      1.300000
# 50%          6.000000      1.960000      1.960000      1.960000      1.955000
# 75%          9.000000      3.850000      3.850000      3.850000      3.850000
# max         11.000000  51515.130000  51515.130000  51515.130000  51515.130000
#
#        odd_entrada5  odd_entrada6  odd_entrada7  odd_entrada8  odd_entrada9  \
# count   5000.000000   5000.000000   5000.000000   5000.000000   5000.000000
# mean      21.602122     21.601094     21.604798     21.604916     21.604842
# std      770.490921    770.490944    770.490892    770.490889    770.490891
# min        1.000000      1.000000      1.000000      1.000000      1.000000
# 25%        1.300000      1.300000      1.300000      1.300000      1.300000
# 50%        1.960000      1.955000      1.960000      1.960000      1.960000
# 75%        3.850000      3.850000      3.850000      3.850000      3.850000
# max    51515.130000  51515.130000  51515.130000  51515.130000  51515.130000
#
#        ...  odd_entrada135  odd_entrada136  odd_entrada137  odd_entrada138  \
# count  ...     5000.000000     5000.000000     5000.000000     5000.000000
# mean   ...       21.766780       21.766906       21.767158       21.767454
# std    ...      770.511174      770.511171      770.511165      770.511157
# min    ...        1.000000        1.000000        1.000000        1.000000
# 25%    ...        1.300000        1.300000        1.300000        1.300000
# 50%    ...        1.960000        1.960000        1.960000        1.960000
# 75%    ...        3.860000        3.860000        3.862500        3.862500
# max    ...    51515.130000    51515.130000    51515.130000    51515.130000
#
#        odd_entrada139  odd_entrada140  odd_entrada141  odd_entrada142  \
# count     5000.000000     5000.000000     5000.000000     5000.000000
# mean        21.767466       21.766238       21.764460       21.764742
# std        770.511157      770.511185      770.511222      770.511215
# min          1.000000        1.000000        1.000000        1.000000
# 25%          1.300000        1.300000        1.300000        1.300000
# 50%          1.960000        1.960000        1.960000        1.960000
# 75%          3.862500        3.860000        3.860000        3.860000
# max      51515.130000    51515.130000    51515.130000    51515.130000
#
#        odd_entrada143  odd_entrada144
# count     5000.000000     5000.000000
# mean        21.764232       21.763774
# std        770.511226      770.511237
# min          1.000000        1.000000
# 25%          1.300000        1.300000
# 50%          1.960000        1.960000
# 75%          3.860000        3.852500
# max      51515.130000    51515.130000
#
# [8 rows x 145 columns]

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
from collections import deque
import random
import matplotlib.pyplot as plt


class DQNAgent:
  def __init__(self, n_states, n_actions, learning_rate, gamma, epsilon, buffer_size=10000):
        self.n_states = n_states
        self.n_actions = n_actions
        self.learning_rate = learning_rate
        self.gamma = gamma
        self.epsilon = epsilon
        self.memory = deque(maxlen=buffer_size)

        # Crie a rede neural
        self.model = self.build_model()
        self.model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
                           loss='sparse_categorical_crossentropy')

  def build_model(self):
        model = tf.keras.Sequential([
            tf.keras.layers.Input(shape=(self.n_states,)),
            tf.keras.layers.Dense(256, activation='relu'),
            tf.keras.layers.Dense(256, activation='relu'),
            tf.keras.layers.Dense(self.n_actions, activation='softmax')
        ])
        return model

  def get_action(self, state):
    if np.random.random() < self.epsilon:
      return np.random.choice(self.n_actions)
    else:
      q_values = self.model.predict(state.reshape(1, -1), batch_size=100)
      return np.argmax(q_values)

  def remember(self, state, action, reward, next_state, done):
    self.memory.append((state, action, reward, next_state, done))

    # Restante do código permanece igual até o método 'replay'
  def replay(self, batch_size):
        if len(self.memory) < batch_size:
            return
        minibatch = random.sample(self.memory, batch_size)
        for state, action, reward, next_state, done in minibatch:
            target = reward
            if not done:
                target = (reward + self.gamma * np.amax(self.model.predict(next_state.reshape(1, -1), batch_size=100)))
            target_f = self.model.predict(state.reshape(1, -1), batch_size=100)
            target_f[0][action] = target
            self.model.fit(state.reshape(1, -1), np.array([action]), epochs=50, verbose=1, batch_size=batch_size)

  def update_epsilon(self, decay_rate, min_epsilon):
    if self.epsilon > min_epsilon:
      self.epsilon *= decay_rate

def calculate_reward(action, true_action):
  base_reward = 10  # Recompensa base para acertos exatos
  good_error_reward = 5  # Recompensa para erros bons
  bad_error_penalty = -5  # Penalidade para erros ruins

  # Recompensas e penalidades adicionais para categorias específicas
  extra_good_reward = 3  # Recompensa adicional para erros bons próximos a categorias valiosas
  extra_bad_penalty = -3  # Penalidade adicional para erros ruins próximos a categorias valiosas
  valuable_categories = [7, 8, 9, 10, 11]

  if action == true_action:
    return base_reward
  elif action < true_action:
    reward = good_error_reward
    if true_action in valuable_categories and action in valuable_categories:
      reward += extra_good_reward  # Recompensa extra por estar próximo de categorias valiosas
    return reward
  else:
    penalty = bad_error_penalty
    if true_action in valuable_categories or action in valuable_categories:
      penalty += extra_bad_penalty  # Penalidade extra por estar distante de categorias valiosas
    return penalty


def normalize_data(features):
  scaler = StandardScaler()
  return scaler.fit_transform(features)

def main():
# Recursos (variáveis de entrada)
  features = data[['odd_entrada1', 'odd_entrada2', 'odd_entrada3',
       'odd_entrada4', 'odd_entrada5', 'odd_entrada6', 'odd_entrada7',
       'odd_entrada8', 'odd_entrada9', 'odd_entrada10', 'odd_entrada11',
       'odd_entrada12', 'odd_entrada13', 'odd_entrada14', 'odd_entrada15',
       'odd_entrada16', 'odd_entrada17', 'odd_entrada18', 'odd_entrada19',
       'odd_entrada20', 'odd_entrada21', 'odd_entrada22', 'odd_entrada23',
       'odd_entrada24', 'odd_entrada25', 'odd_entrada26', 'odd_entrada27',
       'odd_entrada28', 'odd_entrada29', 'odd_entrada30', 'odd_entrada31',
       'odd_entrada32', 'odd_entrada33', 'odd_entrada34', 'odd_entrada35',
       'odd_entrada36', 'odd_entrada37', 'odd_entrada38', 'odd_entrada39',
       'odd_entrada40', 'odd_entrada41', 'odd_entrada42', 'odd_entrada43',
       'odd_entrada44', 'odd_entrada45', 'odd_entrada46', 'odd_entrada47',
       'odd_entrada48', 'odd_entrada49', 'odd_entrada50', 'odd_entrada51',
       'odd_entrada52', 'odd_entrada53', 'odd_entrada54', 'odd_entrada55',
       'odd_entrada56', 'odd_entrada57', 'odd_entrada58', 'odd_entrada59',
       'odd_entrada60', 'odd_entrada61', 'odd_entrada62', 'odd_entrada63',
       'odd_entrada64', 'odd_entrada65', 'odd_entrada66', 'odd_entrada67',
       'odd_entrada68', 'odd_entrada69', 'odd_entrada70', 'odd_entrada71',
       'odd_entrada72', 'odd_entrada73', 'odd_entrada74', 'odd_entrada75',
       'odd_entrada76', 'odd_entrada77', 'odd_entrada78', 'odd_entrada79',
       'odd_entrada80', 'odd_entrada81', 'odd_entrada82', 'odd_entrada83',
       'odd_entrada84', 'odd_entrada85', 'odd_entrada86', 'odd_entrada87',
       'odd_entrada88', 'odd_entrada89', 'odd_entrada90', 'odd_entrada91',
       'odd_entrada92', 'odd_entrada93', 'odd_entrada94', 'odd_entrada95',
       'odd_entrada96', 'odd_entrada97', 'odd_entrada98', 'odd_entrada99',
       'odd_entrada100', 'odd_entrada101', 'odd_entrada102', 'odd_entrada103',
       'odd_entrada104', 'odd_entrada105', 'odd_entrada106', 'odd_entrada107',
       'odd_entrada108', 'odd_entrada109', 'odd_entrada110', 'odd_entrada111',
       'odd_entrada112', 'odd_entrada113', 'odd_entrada114', 'odd_entrada115',
       'odd_entrada116', 'odd_entrada117', 'odd_entrada118', 'odd_entrada119',
       'odd_entrada120', 'odd_entrada121', 'odd_entrada122', 'odd_entrada123',
       'odd_entrada124', 'odd_entrada125', 'odd_entrada126', 'odd_entrada127',
       'odd_entrada128', 'odd_entrada129', 'odd_entrada130', 'odd_entrada131',
       'odd_entrada132', 'odd_entrada133', 'odd_entrada134', 'odd_entrada135',
       'odd_entrada136', 'odd_entrada137', 'odd_entrada138', 'odd_entrada139',
       'odd_entrada140', 'odd_entrada141', 'odd_entrada142', 'odd_entrada143',
       'odd_entrada144']].values

  # Recompensas (variável de saída)
  rewards = data['Odd_Categoria1'].values
  features = normalize_data(features)
  # Separe os dados em treino e teste
  X_train, X_test, y_train, y_test = train_test_split(features, rewards, test_size=0.2, random_state=42)

  # Parâmetros de treinamento
  n_epochs = 25  # Número de épocas de treinamento
  batch_size = 64  # Tamanho do lote para treinamento

  # Crie o agente DQN
  n_states = X_train.shape[1]
  n_actions = len(np.unique(y_train))
  dqn_agent = DQNAgent(n_states, n_actions, learning_rate=0.001, gamma=0.99, epsilon=1.0, buffer_size=10000)

  epoch_accuracies = []
  epoch_directional_accuracies = []
  epoch_weighted_directional_accuracies = []

  # Treinamento do agente
  for epoch in range(n_epochs):
      # Inicializa as métricas para cada época
      correct_predictions, overestimations, weighted_correct_predictions, weighted_overestimations = 0, 0, 0, 0

      for i in range(len(X_train) - 1):
          state = X_train[i, :]
          action = dqn_agent.get_action(state)
          true_action = y_train[i]
          reward = calculate_reward(action, true_action)
          next_state = X_train[i + 1, :]
          done = (i == len(X_train) - 2)

          dqn_agent.remember(state, action, reward, next_state, done)

          if done:
              dqn_agent.replay(batch_size)
              dqn_agent.update_epsilon(0.995, 0.01)

          # Atualiza as métricas
          if action == true_action:
              correct_predictions += 1
              weighted_correct_predictions += 2  # Peso maior para acertos exatos
          elif action > true_action:
              overestimations += 1
              weighted_overestimations += 1  # Peso menor para erros

      # Calcula as métricas para a época
      epoch_accuracy = correct_predictions / len(X_test)
      epoch_directional_accuracy = (correct_predictions + overestimations) / len(X_test)
      epoch_weighted_directional_accuracy = (weighted_correct_predictions + weighted_overestimations) / len(X_test)

      epoch_accuracies.append(epoch_accuracy)
      epoch_directional_accuracies.append(epoch_directional_accuracy)
      epoch_weighted_directional_accuracies.append(epoch_weighted_directional_accuracy)

  # Inicialize listas para coletar dados de erro
  erros = []
  tipos_de_erro = {'subestimacao': [], 'superestimacao': []}
  # Teste o agente
  correct_predictions = 0
  overestimations = 0
  weighted_correct_predictions = 0
  weighted_overestimations = 0

  predicted_actions = []

  for i in range(len(X_test)):
    state = X_test[i, :]
    action = dqn_agent.get_action(state)
    true_action = y_test[i]

    predicted_actions.append(action)

    # Cálculo do erro
    erro = action - true_action
    erros.append(erro)

    # Classificando o tipo de erro
    if erro < 0:
      tipos_de_erro['subestimacao'].append(erro)
    elif erro > 0:
      tipos_de_erro['superestimacao'].append(erro)

    # Atualize as métricas
    if action == true_action:
      correct_predictions += 1
      weighted_correct_predictions += 2  # Peso maior para acertos
    elif action > true_action:
      overestimations += 1
      weighted_overestimations += 1  # Peso menor para erros

    # Calcule a precisão
  accuracy = correct_predictions / len(X_test)

    # Calcule a Acurácia Direcional
  directional_accuracy = (correct_predictions + overestimations) / len(X_test)

    # Calcule a Acurácia Direcional Ponderada
  weighted_directional_accuracy = (weighted_correct_predictions + weighted_overestimations) / len(X_test)

  print("Precisão:", accuracy)
  print("Acurácia Direcional:", directional_accuracy)
  print("Acurácia Direcional Ponderada:", weighted_directional_accuracy)

  # Gráfico das métricas

  plt.figure(figsize=(12, 6))
  plt.plot(epoch_accuracies, label='Precisão')
  plt.plot(epoch_directional_accuracies, label='Acurácia Direcional')
  plt.plot(epoch_weighted_directional_accuracies, label='Acurácia Direcional Ponderada')
  plt.xlabel('Época')
  plt.ylabel('Métrica')
  plt.title('Desempenho do Modelo ao Longo das Épocas')
  plt.legend()
  plt.show()

  plt.figure(figsize=(10, 5))
  metrics = [accuracy, directional_accuracy, weighted_directional_accuracy]
  metric_labels = ['Precisão', 'Acurácia Direcional', 'Acurácia Direcional Ponderada']
  colors = ['blue', 'orange', 'green']
  plt.bar(metric_labels, metrics, color=colors)
  plt.xlabel('Métricas')
  plt.ylabel('Valor')
  plt.title('Métricas de Desempenho no Conjunto de Teste')
  plt.ylim(0, 1)  # As métricas de acurácia devem estar entre 0 e 1
  plt.show()

  # Gráfico de linha das previsões vs reais
  # Criando um eixo x que é uma sequência de inteiros do mesmo tamanho que y_test
  x_axis = np.arange(len(y_test))
  plt.figure(figsize=(15, 5))
  plt.plot(x_axis, y_test, label='Valores Reais', color='blue')
  plt.plot(x_axis, predicted_actions, label='Previsões do Modelo', color='orange', linestyle='--')
  plt.xlabel('Exemplo')
  plt.ylabel('Categorias')
  plt.title('Comparação das Previsões do Modelo com os Valores Reais')
  plt.legend()
  plt.show()

  dqn_agent.model.save('AgenteAv.h5')
  data_save = pd.DataFrame({'epoch_accuracies': epoch_accuracies,
               'epoch_directional_accuracies': epoch_directional_accuracies,
               'epoch_weighted_directional_accuracies': epoch_weighted_directional_accuracies}).to_csv('metricas.csv')

if __name__ == "__main__":
  main()
# Out:
# Streaming output truncated to the last 5000 lines.
# Epoch 5/50
# 1/1 [==============================] - 0s 8ms/step - loss: 2.8929
# Epoch 6/50
# 1/1 [==============================] - 0s 8ms/step - loss: 2.8461
# Epoch 7/50
# 1/1 [==============================] - 0s 7ms/step - loss: 2.7941
# Epoch 8/50
# 1/1 [==============================] - 0s 7ms/step - loss: 2.7380
# Epoch 9/50
# 1/1 [==============================] - 0s 8ms/step - loss: 2.6789
# Epoch 10/50
# 1/1 [==============================] - 0s 9ms/step - loss: 2.6175
# Epoch 11/50
# 1/1 [==============================] - 0s 9ms/step - loss: 2.5546
# Epoch 12/50
# 1/1 [==============================] - 0s 8ms/step - loss: 2.4907
# Epoch 13/50
# 1/1 [==============================] - 0s 9ms/step - loss: 2.4264
# Epoch 14/50
# 1/1 [==============================] - 0s 9ms/step - loss: 2.3619
# Epoch 15/50
# 1/1 [==============================] - 0s 8ms/step - loss: 2.2977
# Epoch 16/50
# 1/1 [==============================] - 0s 9ms/step - loss: 2.2338
# Epoch 17/50
# 1/1 [==============================] - 0s 8ms/step - loss: 2.1706
# Epoch 18/50
# 1/1 [==============================] - 0s 10ms/step - loss: 2.1080
# Epoch 19/50
# 1/1 [==============================] - 0s 9ms/step - loss: 2.0462
# Epoch 20/50
# 1/1 [==============================] - 0s 10ms/step - loss: 1.9852
# Epoch 21/50
# 1/1 [==============================] - 0s 8ms/step - loss: 1.9250
# Epoch 22/50
# 1/1 [==============================] - 0s 7ms/step - loss: 1.8656
# Epoch 23/50
# 1/1 [==============================] - 0s 9ms/step - loss: 1.8069
# Epoch 24/50
# 1/1 [==============================] - 0s 8ms/step - loss: 1.7491
# Epoch 25/50
# 1/1 [==============================] - 0s 7ms/step - loss: 1.6919
# Epoch 26/50
# 1/1 [==============================] - 0s 7ms/step - loss: 1.6355
# Epoch 27/50
# 1/1 [==============================] - 0s 9ms/step - loss: 1.5797
# Epoch 28/50
# 1/1 [==============================] - 0s 8ms/step - loss: 1.5245
# Epoch 29/50
# 1/1 [==============================] - 0s 10ms/step - loss: 1.4700
# Epoch 30/50
# 1/1 [==============================] - 0s 9ms/step - loss: 1.4161
# Epoch 31/50
# 1/1 [==============================] - 0s 9ms/step - loss: 1.3628
# Epoch 32/50
# 1/1 [==============================] - 0s 8ms/step - loss: 1.3102
# Epoch 33/50
# 1/1 [==============================] - 0s 9ms/step - loss: 1.2582
# Epoch 34/50
# 1/1 [==============================] - 0s 9ms/step - loss: 1.2070
# Epoch 35/50
# 1/1 [==============================] - 0s 9ms/step - loss: 1.1565
# Epoch 36/50
# 1/1 [==============================] - 0s 8ms/step - loss: 1.1067
# Epoch 37/50
# 1/1 [==============================] - 0s 8ms/step - loss: 1.0578
# Epoch 38/50
# 1/1 [==============================] - 0s 9ms/step - loss: 1.0099
# Epoch 39/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.9629
# Epoch 40/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.9169
# Epoch 41/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.8721
# Epoch 42/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.8273
# Epoch 43/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.7825
# Epoch 44/50
# 1/1 [==============================] - 0s 9ms/step - loss: 0.7384
# Epoch 45/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.6957
# Epoch 46/50
# 1/1 [==============================] - 0s 9ms/step - loss: 0.6545
# Epoch 47/50
# 1/1 [==============================] - 0s 9ms/step - loss: 0.6191
# Epoch 48/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.5880
# Epoch 49/50
# 1/1 [==============================] - 0s 6ms/step - loss: 0.5574
# Epoch 50/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.5277
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 54ms/step
# Epoch 1/50
# 1/1 [==============================] - 0s 10ms/step - loss: 6.4309
# Epoch 2/50
# 1/1 [==============================] - 0s 11ms/step - loss: 6.2773
# Epoch 3/50
# 1/1 [==============================] - 0s 9ms/step - loss: 6.0290
# Epoch 4/50
# 1/1 [==============================] - 0s 10ms/step - loss: 5.7248
# Epoch 5/50
# 1/1 [==============================] - 0s 7ms/step - loss: 5.3914
# Epoch 6/50
# 1/1 [==============================] - 0s 7ms/step - loss: 5.0207
# Epoch 7/50
# 1/1 [==============================] - 0s 7ms/step - loss: 4.6357
# Epoch 8/50
# 1/1 [==============================] - 0s 8ms/step - loss: 4.2459
# Epoch 9/50
# 1/1 [==============================] - 0s 8ms/step - loss: 3.8580
# Epoch 10/50
# 1/1 [==============================] - 0s 7ms/step - loss: 3.4798
# Epoch 11/50
# 1/1 [==============================] - 0s 8ms/step - loss: 3.1316
# Epoch 12/50
# 1/1 [==============================] - 0s 7ms/step - loss: 2.8053
# Epoch 13/50
# 1/1 [==============================] - 0s 7ms/step - loss: 2.5001
# Epoch 14/50
# 1/1 [==============================] - 0s 8ms/step - loss: 2.2361
# Epoch 15/50
# 1/1 [==============================] - 0s 8ms/step - loss: 2.0165
# Epoch 16/50
# 1/1 [==============================] - 0s 10ms/step - loss: 1.8588
# Epoch 17/50
# 1/1 [==============================] - 0s 8ms/step - loss: 1.7157
# Epoch 18/50
# 1/1 [==============================] - 0s 8ms/step - loss: 1.5853
# Epoch 19/50
# 1/1 [==============================] - 0s 8ms/step - loss: 1.5066
# Epoch 20/50
# 1/1 [==============================] - 0s 10ms/step - loss: 1.4436
# Epoch 21/50
# 1/1 [==============================] - 0s 7ms/step - loss: 1.3842
# Epoch 22/50
# 1/1 [==============================] - 0s 7ms/step - loss: 1.3274
# Epoch 23/50
# 1/1 [==============================] - 0s 8ms/step - loss: 1.2726
# Epoch 24/50
# 1/1 [==============================] - 0s 8ms/step - loss: 1.2194
# Epoch 25/50
# 1/1 [==============================] - 0s 9ms/step - loss: 1.1676
# Epoch 26/50
# 1/1 [==============================] - 0s 9ms/step - loss: 1.1170
# Epoch 27/50
# 1/1 [==============================] - 0s 7ms/step - loss: 1.0676
# Epoch 28/50
# 1/1 [==============================] - 0s 8ms/step - loss: 1.0195
# Epoch 29/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.9725
# Epoch 30/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.9269
# Epoch 31/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.8812
# Epoch 32/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.8343
# Epoch 33/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.7878
# Epoch 34/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.7421
# Epoch 35/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.6976
# Epoch 36/50
# 1/1 [==============================] - 0s 9ms/step - loss: 0.6546
# Epoch 37/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.6134
# Epoch 38/50
# 1/1 [==============================] - 0s 6ms/step - loss: 0.5741
# Epoch 39/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.5368
# Epoch 40/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.5014
# Epoch 41/50
# 1/1 [==============================] - 0s 9ms/step - loss: 0.4682
# Epoch 42/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.4369
# Epoch 43/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.4077
# Epoch 44/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.3803
# Epoch 45/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.3549
# Epoch 46/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.3312
# Epoch 47/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.3092
# Epoch 48/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.2888
# Epoch 49/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.2699
# Epoch 50/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.2524
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# Epoch 1/50
# 1/1 [==============================] - 0s 10ms/step - loss: 0.7134
# Epoch 2/50
# 1/1 [==============================] - 0s 9ms/step - loss: 0.7203
# Epoch 3/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.7217
# Epoch 4/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.7180
# Epoch 5/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.7099
# Epoch 6/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.6980
# Epoch 7/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.6828
# Epoch 8/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.6649
# Epoch 9/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.6448
# Epoch 10/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.6229
# Epoch 11/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.5998
# Epoch 12/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.5758
# Epoch 13/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.5512
# Epoch 14/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.5264
# Epoch 15/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.5016
# Epoch 16/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.4771
# Epoch 17/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.4528
# Epoch 18/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.4261
# Epoch 19/50
# 1/1 [==============================] - 0s 10ms/step - loss: 0.3996
# Epoch 20/50
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3737
# Epoch 21/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.3488
# Epoch 22/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.3249
# Epoch 23/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.3024
# Epoch 24/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.2811
# Epoch 25/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2612
# Epoch 26/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.2427
# Epoch 27/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.2255
# Epoch 28/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.2097
# Epoch 29/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1950
# Epoch 30/50
# 1/1 [==============================] - 0s 9ms/step - loss: 0.1816
# Epoch 31/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1692
# Epoch 32/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1579
# Epoch 33/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1476
# Epoch 34/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1383
# Epoch 35/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1295
# Epoch 36/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1215
# Epoch 37/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1143
# Epoch 38/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1077
# Epoch 39/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1016
# Epoch 40/50
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0961
# Epoch 41/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0910
# Epoch 42/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0863
# Epoch 43/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0820
# Epoch 44/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0780
# Epoch 45/50
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0744
# Epoch 46/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0710
# Epoch 47/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0679
# Epoch 48/50
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0650
# Epoch 49/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0623
# Epoch 50/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0598
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# Epoch 1/50
# 1/1 [==============================] - 0s 11ms/step - loss: 5.5702
# Epoch 2/50
# 1/1 [==============================] - 0s 9ms/step - loss: 5.4308
# Epoch 3/50
# 1/1 [==============================] - 0s 7ms/step - loss: 5.1927
# Epoch 4/50
# 1/1 [==============================] - 0s 8ms/step - loss: 4.8820
# Epoch 5/50
# 1/1 [==============================] - 0s 8ms/step - loss: 4.5341
# Epoch 6/50
# 1/1 [==============================] - 0s 7ms/step - loss: 4.1928
# Epoch 7/50
# 1/1 [==============================] - 0s 7ms/step - loss: 3.8327
# Epoch 8/50
# 1/1 [==============================] - 0s 7ms/step - loss: 3.4632
# Epoch 9/50
# 1/1 [==============================] - 0s 7ms/step - loss: 3.0745
# Epoch 10/50
# 1/1 [==============================] - 0s 7ms/step - loss: 2.6837
# Epoch 11/50
# 1/1 [==============================] - 0s 7ms/step - loss: 2.3434
# Epoch 12/50
# 1/1 [==============================] - 0s 8ms/step - loss: 2.0467
# Epoch 13/50
# 1/1 [==============================] - 0s 8ms/step - loss: 1.7929
# Epoch 14/50
# 1/1 [==============================] - 0s 8ms/step - loss: 1.5840
# Epoch 15/50
# 1/1 [==============================] - 0s 9ms/step - loss: 1.4180
# Epoch 16/50
# 1/1 [==============================] - 0s 6ms/step - loss: 1.2942
# Epoch 17/50
# 1/1 [==============================] - 0s 8ms/step - loss: 1.1939
# Epoch 18/50
# 1/1 [==============================] - 0s 8ms/step - loss: 1.1166
# Epoch 19/50
# 1/1 [==============================] - 0s 8ms/step - loss: 1.0310
# Epoch 20/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.9524
# Epoch 21/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.8670
# Epoch 22/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.7748
# Epoch 23/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.6801
# Epoch 24/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.5852
# Epoch 25/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.4959
# Epoch 26/50
# 1/1 [==============================] - 0s 6ms/step - loss: 0.4148
# Epoch 27/50
# 1/1 [==============================] - 0s 6ms/step - loss: 0.3440
# Epoch 28/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.2834
# Epoch 29/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2327
# Epoch 30/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1911
# Epoch 31/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1577
# Epoch 32/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1311
# Epoch 33/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1096
# Epoch 34/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0923
# Epoch 35/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0782
# Epoch 36/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0668
# Epoch 37/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0575
# Epoch 38/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0500
# Epoch 39/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0437
# Epoch 40/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0386
# Epoch 41/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0343
# Epoch 42/50
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0307
# Epoch 43/50
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0276
# Epoch 44/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0251
# Epoch 45/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0229
# Epoch 46/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0210
# Epoch 47/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0194
# Epoch 48/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0180
# Epoch 49/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0168
# Epoch 50/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0158
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# Epoch 1/50
# 1/1 [==============================] - 0s 9ms/step - loss: 3.6404
# Epoch 2/50
# 1/1 [==============================] - 0s 8ms/step - loss: 3.5940
# Epoch 3/50
# 1/1 [==============================] - 0s 8ms/step - loss: 3.4996
# Epoch 4/50
# 1/1 [==============================] - 0s 8ms/step - loss: 3.3729
# Epoch 5/50
# 1/1 [==============================] - 0s 8ms/step - loss: 3.2233
# Epoch 6/50
# 1/1 [==============================] - 0s 8ms/step - loss: 3.0579
# Epoch 7/50
# 1/1 [==============================] - 0s 8ms/step - loss: 2.8864
# Epoch 8/50
# 1/1 [==============================] - 0s 8ms/step - loss: 2.7279
# Epoch 9/50
# 1/1 [==============================] - 0s 9ms/step - loss: 2.5680
# Epoch 10/50
# 1/1 [==============================] - 0s 8ms/step - loss: 2.