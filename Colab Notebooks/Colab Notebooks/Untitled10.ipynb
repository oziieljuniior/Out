# %%
import pandas as pd
import numpy as np
import re
import datetime as dt
from datetime import timedelta, datetime, time
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.regularizers import l2
import tensorflow as tf
import seaborn as sns
import matplotlib.pyplot as plt
from tensorflow import keras
from scipy.stats import entropy
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score, f1_score

# %%
path = '/content/drive/MyDrive/Aviator/Data1/bd_pseudo_1.csv'
data = pd.read_csv(path)
print(data)
t = 0
print(len(data))
t0 = int(input("Maximo: "))
tamanho_data = len(data)

odd = []
horario = []
odd_ajustada = []

while t <= t0:
    if t < tamanho_data:
        value = data['odd'][t]
        if isinstance(value, float):
            odd.append(np.nan)  # or any other value to represent missing data
        else:
            aux = value.split('\n\n')
            a1 = aux[0].replace(')I', '')
            a2 = a1.replace(')', '')
            a3 = a2.replace('|', '1')
            a4 = a3.replace('?', '7')
            a5 = re.sub('[^0-9.]', '', a4)
            odd.append(float(a5))
        horario.append(data['hora_criacao'][t])

    t += 1

for name in odd:
    ajuste = float(name - 1.25)
    odd_ajustada.append(ajuste)

horas = []
minutos = []
segundos = []
for item in horario:
    dt = datetime.strptime(item, "%a %b %d %H:%M:%S %Y")
    horas.append(dt.hour)
    minutos.append(dt.minute)
    segundos.append(dt.second)

data1 = pd.DataFrame({'Odd_ajustada': odd, 'hora': horas, 'minutos': minutos, 'segundos': segundos, 'horario': horario})

###Data final
#data = dados_filtrados
data = data1

# Verificar se existem valores NaN na coluna "Odd_ajustada"
has_nan = data['Odd_ajustada'].isna().any()
if has_nan:
    print("Existem valores NaN na coluna 'Odd_ajustada'.")
else:
    print("Não existem valores NaN na coluna 'Odd_ajustada'.")
# Out:
#           id    odd              hora_criacao apostadores
# 0          0  13.89  Sat May 27 00:28:06 2023        1650
# 1          1   1.44  Sat May 27 00:28:18 2023       22211
# 2          2   3.39  Sat May 27 00:28:42 2023        1751
# 3          3   1.27  Sat May 27 00:28:56 2023        1950
# 4          4   5.16  Sat May 27 00:29:26 2023        2086
# ...      ...    ...                       ...         ...
# 37852  37855   1.53  Fri Oct 20 23:00:27 2023
# 37853  37856   1.36  Fri Oct 20 23:00:45 2023        181
# 37854  37857   1.00  Fri Oct 20 23:00:59 2023       1882
# 37855  37858   2.17  Fri Oct 20 23:01:20 2023          1
# 37856  37859   2.12  Fri Oct 20 23:01:46 2023
#
# [37857 rows x 4 columns]
# 37857
# Maximo: 37857
# Não existem valores NaN na coluna 'Odd_ajustada'.

# %%
data1 = data

# %%
geral_cat = []
for name in data['Odd_ajustada']:
  #print(name)
  if name < 1.05:
    geral_cat.append(1)
  elif name >= 1.05 and name < 1.15:
    geral_cat.append(2)
  elif name >= 1.15 and name < 1.3:
    geral_cat.append(3)
  elif name >= 1.3 and name < 1.45:
    geral_cat.append(4)
  elif name >= 1.45 and name < 1.7:
    geral_cat.append(5)
  elif name >= 1.7 and name < 2.1:
    geral_cat.append(6)
  elif name >= 2.1 and name < 2.6:
    geral_cat.append(7)
  elif name >= 2.6 and name < 3.5:
    geral_cat.append(8)
  elif name >= 3.5 and name < 5:
    geral_cat.append(9)
  elif name >= 5 and name < 10:
    geral_cat.append(10)
  elif name >= 10:
    geral_cat.append(11)
print(len(geral_cat))
geral_cat1 = pd.DataFrame([geral_cat]).T
geral_cat1.columns = ['Odd_Categoria']
data = pd.concat([data, geral_cat1], axis = 1)

data['Odd_Categoria'].describe()
# Out:
# 37857
# count    37857.000000
# mean         6.114536
# std          3.090147
# min          1.000000
# 25%          3.000000
# 50%          6.000000
# 75%          9.000000
# max         11.000000
# Name: Odd_Categoria, dtype: float64

# %%
# Configurar o histograma
plt.hist(data['Odd_Categoria'], bins=11, edgecolor='k')  # O número de bins deve corresponder ao número de classes (12 no seu caso)
plt.title('Histograma da coluna Odd_Categoria')
plt.xlabel('Classes')
plt.ylabel('Frequência')
plt.xticks(range(1, 12))  # Rótulos do eixo x de 1 a 12
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Mostrar o histograma
plt.show()

# %%
# Crie as colunas "entrada" e "saida" deslocando a coluna "horario" para cima
new_data = pd.DataFrame()
new_data['odd_saida'] = data['Odd_Categoria']
new_data['odd_eentrada'] = data['Odd_Categoria'].shift(1)

new_data = new_data.drop(new_data.index[0])
# Visualize o DataFrame new_data
print(new_data)

data = pd.concat([data, new_data], axis = 1)

data = data.drop(data.index[0])
# Out:
#        odd_saida  odd_eentrada
# 1              4          11.0
# 2              8           4.0
# 3              3           8.0
# 4             10           3.0
# 5              8          10.0
# ...          ...           ...
# 37852          5          11.0
# 37853          4           5.0
# 37854          1           4.0
# 37855          7           1.0
# 37856          7           7.0
#
# [37856 rows x 2 columns]

# %%
data['odd_categoria_media_movel5'] = data['odd_eentrada'].rolling(window=5).mean()
data['odd_categoria_media_movel10'] = data['odd_eentrada'].rolling(window=10).mean()
data['odd_categoria_media_movel20'] = data['odd_eentrada'].rolling(window=20).mean()
data['odd_categoria_media_movel40'] = data['odd_eentrada'].rolling(window=40).mean()
data['odd_categoria_media_movel80'] = data['odd_eentrada'].rolling(window=80).mean()
data['odd_categoria_media_movel160'] = data['odd_eentrada'].rolling(window=160).mean()
data['odd_categoria_media_movel320'] = data['odd_eentrada'].rolling(window=320).mean()
data['odd_categoria_media_movel640'] = data['odd_eentrada'].rolling(window=640).mean()

data = data.fillna(data.mean())  # Preencher com a média da coluna

# Estatísticas Descritivas
data['odd_mediana20'] = data['odd_eentrada'].rolling(window=20).median()

data['odd_min10'] = data['odd_eentrada'].rolling(window=10).min()
data['odd_min20'] = data['odd_eentrada'].rolling(window=20).min()
data['odd_min40'] = data['odd_eentrada'].rolling(window=40).min()

data['odd_max10'] = data['odd_eentrada'].rolling(window=10).max()

# Tendência de Média Móvel
data['tendencia_media_movel10'] = data['odd_categoria_media_movel10'].diff()

# Frequência de Categorias (assumindo que 'Odd_Categoria' é categórico)
data['categoria_frequencia20'] = data['odd_eentrada'].rolling(window=20).apply(lambda x: x.value_counts().idxmax())

data['entropia_rolling5'] = data['odd_eentrada'].rolling(window=5).apply(lambda x: entropy(x.value_counts(normalize=True)))
data['entropia_rolling320'] = data['odd_eentrada'].rolling(window=320).apply(lambda x: entropy(x.value_counts(normalize=True)))

# Correlações (exemplo com 'media_movel_segundo5')
data['correlacao_odd_categoria_media_movel10'] = data['odd_eentrada'].rolling(window=10).corr(data['odd_categoria_media_movel10'])
data['correlacao_odd_categoria_media_movel640'] = data['odd_eentrada'].rolling(window=640).corr(data['odd_categoria_media_movel640'])

data['correlacao_odd_categoria_media_movel10'].replace([np.inf, -np.inf], np.nan, inplace=True)
data['correlacao_odd_categoria_media_movel640'].replace([np.inf, -np.inf], np.nan, inplace=True)

# Contagem de repetições das categorias
data['categoria_contagem'] = data['odd_eentrada'].map(data['odd_eentrada'].value_counts())

data['variancia_rolling10'] = data['odd_eentrada'].rolling(window=10).var()
data['variancia_rolling20'] = data['odd_eentrada'].rolling(window=20).var()
data['variancia_rolling320'] = data['odd_eentrada'].rolling(window=320).var()

# Remova linhas com valores ausentes resultantes das operações de janelas
data = data.fillna(data.mean())

# Verifique se há valores nulos em cada coluna
valores_ausentes = data.isna().sum()

# Exiba as colunas com valores nulos e suas contagens
print(valores_ausentes[valores_ausentes > 0])

data.head(20)
data.shape
# Out:
# <ipython-input-7-6640d173463f>:10: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data = data.fillna(data.mean())  # Preencher com a média da coluna
# Series([], dtype: int64)
# <ipython-input-7-6640d173463f>:45: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data = data.fillna(data.mean())
# (37856, 31)

# %%
# Calculando a matriz de correlação
corr_matrix = data.corr()

# Criando o heatmap
plt.figure(figsize=(20, 20))
sns.heatmap(corr_matrix, annot=False, cmap="coolwarm", linewidths=.5)
plt.title('Correlation heatmap')
plt.show()
# Out:
# <ipython-input-8-516b264cc2dd>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = data.corr()

# %%
data.columns
# Out:
# Index(['Odd_ajustada', 'hora', 'minutos', 'segundos', 'horario',
#        'Odd_Categoria', 'odd_saida', 'odd_eentrada',
#        'odd_categoria_media_movel5', 'odd_categoria_media_movel10',
#        'odd_categoria_media_movel20', 'odd_categoria_media_movel40',
#        'odd_categoria_media_movel80', 'odd_categoria_media_movel160',
#        'odd_categoria_media_movel320', 'odd_categoria_media_movel640',
#        'odd_mediana20', 'odd_min10', 'odd_min20', 'odd_min40', 'odd_max10',
#        'tendencia_media_movel10', 'categoria_frequencia20',
#        'entropia_rolling5', 'entropia_rolling320',
#        'correlacao_odd_categoria_media_movel10',
#        'correlacao_odd_categoria_media_movel640', 'categoria_contagem',
#        'variancia_rolling10', 'variancia_rolling20', 'variancia_rolling320'],
#       dtype='object')

# %%
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error, r2_score

# Separar recursos (X) e rótulos (y)
X1 = data[['odd_eentrada',
       'odd_categoria_media_movel5', 'odd_categoria_media_movel10',
       'odd_categoria_media_movel20', 'odd_categoria_media_movel40',
       'odd_categoria_media_movel80', 'odd_categoria_media_movel160',
       'odd_categoria_media_movel320', 'odd_categoria_media_movel640',
       'odd_mediana20', 'odd_min10', 'odd_min20', 'odd_min40', 'odd_max10',
       'tendencia_media_movel10', 'categoria_frequencia20',
       'entropia_rolling5', 'entropia_rolling320',
       'correlacao_odd_categoria_media_movel10',
       'correlacao_odd_categoria_media_movel640', 'categoria_contagem',
       'variancia_rolling10', 'variancia_rolling20', 'variancia_rolling320']].values
y1 = data['Odd_Categoria'].values

scaler = StandardScaler()
X1 = scaler.fit_transform(X1)

# Divida os dados em conjuntos de treinamento e teste
X_train, X_test, y_train, y_test = train_test_split(X1, y1, test_size=0.2, random_state=42)

# Crie um modelo SVM para regressão
svm_regressor = SVR(kernel='linear')  # Pode escolher outros kernels também

# Treine o modelo no conjunto de treinamento
svm_regressor.fit(X_train, y_train)

# Faça previsões no conjunto de teste
y_pred = svm_regressor.predict(X_test)

# Avalie o desempenho do modelo
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("Erro Quadrático Médio (MSE):", mse)
print("Coeficiente de Determinação (R^2):", r2)
# Out:
# Erro Quadrático Médio (MSE): 9.598431041874907
# Coeficiente de Determinação (R^2): 0.00039054927867043787

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error, r2_score

# Separar recursos (X) e rótulos (y)
X1 = data[['odd_eentrada',
       'odd_categoria_media_movel5', 'odd_categoria_media_movel10',
       'odd_categoria_media_movel20', 'odd_categoria_media_movel40',
       'odd_categoria_media_movel80', 'odd_categoria_media_movel160',
       'odd_categoria_media_movel320', 'odd_categoria_media_movel640',
       'odd_mediana20', 'odd_min10', 'odd_min20', 'odd_min40', 'odd_max10',
       'tendencia_media_movel10', 'categoria_frequencia20',
       'entropia_rolling5', 'entropia_rolling320',
       'correlacao_odd_categoria_media_movel10',
       'correlacao_odd_categoria_media_movel640', 'categoria_contagem',
       'variancia_rolling10', 'variancia_rolling20', 'variancia_rolling320']].values
y1 = data['Odd_Categoria'].values

scaler = StandardScaler()
X1 = scaler.fit_transform(X1)

# Divida os dados em conjuntos de treinamento e teste
X_train, X_test, y_train, y_test = train_test_split(X1, y1, test_size=0.2, random_state=42)

# Crie e treine o modelo Naive Bayes (usando Gaussian Naive Bayes neste exemplo)
naive_bayes = GaussianNB()
naive_bayes.fit(X_train, y_train)

# Faça previsões
y_pred = naive_bayes.predict(X_test)

# Calcule o erro quadrático médio
mse = mean_squared_error(y_test, y_pred)
print(f"Erro Quadrático Médio (MSE): {mse}")
# Out:
# Erro Quadrático Médio (MSE): 18.113708399366086

# %%
# Separar recursos (X) e rótulos (y)
X1 = data[['odd_eentrada',
       'odd_categoria_media_movel5', 'odd_categoria_media_movel10',
       'odd_categoria_media_movel20', 'odd_categoria_media_movel40',
       'odd_categoria_media_movel80', 'odd_categoria_media_movel160',
       'odd_categoria_media_movel320', 'odd_categoria_media_movel640',
       'odd_mediana20', 'odd_min10', 'odd_min20', 'odd_min40', 'odd_max10',
       'tendencia_media_movel10', 'categoria_frequencia20',
       'entropia_rolling5', 'entropia_rolling320',
       'correlacao_odd_categoria_media_movel10',
       'correlacao_odd_categoria_media_movel640', 'categoria_contagem',
       'variancia_rolling10', 'variancia_rolling20', 'variancia_rolling320']].values
y1 = data['Odd_Categoria'].values

# Normalizar os recursos (importante para redes neurais)
scaler1 = StandardScaler()
X1 = scaler1.fit_transform(X1)

# Dividir os dados em treinamento e teste
X_train1, X_test1, y_train1, y_test1 = train_test_split(X1, y1, test_size=0.2, random_state=42)

# Criar o modelo LSTM com camadas adicionais e dropout
model1 = Sequential()
model1.add(LSTM(320, input_shape=(X_train1.shape[1], 1), return_sequences=True))  # Camada LSTM com retorno de sequência
model1.add(Dropout(0.2))  # Camada de dropout para redução de overfitting
model1.add(LSTM(320))  # Segunda camada LSTM
model1.add(Dense(320, activation='relu', kernel_regularizer=l2(0.001)))  # Camada densa com regularização L2
model1.add(Dense(12, activation='softmax'))  # Camada de saída com ativação softmax para 11 categorias

# Compilar o modelo com uma taxa de aprendizado menor
model1.compile(loss='sparse_categorical_crossentropy', optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), metrics=['accuracy'])

# Treinar o modelo
model_train1 = model1.fit(X_train1.reshape(X_train1.shape[0], X_train1.shape[1], 1), y_train1, epochs=250, batch_size=160, validation_split=0.2)
#model_train

# Avaliar o modelo no conjunto de teste
accuracy = model1.evaluate(X_test1.reshape(X_test1.shape[0], X_test1.shape[1], 1), y_test1)[1]
print(f'Acurácia do modelo: {accuracy}')

# Fazer previsões
predictions = model1.predict(X_test1.reshape(X_test1.shape[0], X_test1.shape[1], 1))

# Arredondar as previsões para obter rótulos de classe
predicted_labels = np.argmax(predictions, axis=1)

# Calcular o F1-Score
f1 = f1_score(y_test1, predicted_labels, average='weighted')

print(f'F1-Score do modelo: {f1}')
# Out:
# Epoch 1/250
# 152/152 [==============================] - 133s 836ms/step - loss: 2.5205 - accuracy: 0.1057 - val_loss: 2.4357 - val_accuracy: 0.1105
# Epoch 2/250
# 152/152 [==============================] - 125s 824ms/step - loss: 2.4164 - accuracy: 0.1075 - val_loss: 2.4046 - val_accuracy: 0.1105
# Epoch 3/250
# 152/152 [==============================] - 123s 807ms/step - loss: 2.4029 - accuracy: 0.1076 - val_loss: 2.3974 - val_accuracy: 0.1105
# Epoch 4/250
# 152/152 [==============================] - 123s 813ms/step - loss: 2.3986 - accuracy: 0.1095 - val_loss: 2.3980 - val_accuracy: 0.1105
# Epoch 5/250
# 152/152 [==============================] - 122s 802ms/step - loss: 2.3967 - accuracy: 0.1098 - val_loss: 2.3969 - val_accuracy: 0.1105
# Epoch 6/250
# 152/152 [==============================] - 123s 813ms/step - loss: 2.3960 - accuracy: 0.1115 - val_loss: 2.3935 - val_accuracy: 0.1105
# Epoch 7/250
# 152/152 [==============================] - 122s 804ms/step - loss: 2.3953 - accuracy: 0.1099 - val_loss: 2.3952 - val_accuracy: 0.1085
# Epoch 8/250
# 152/152 [==============================] - 122s 806ms/step - loss: 2.3944 - accuracy: 0.1114 - val_loss: 2.3952 - val_accuracy: 0.1105
# Epoch 9/250
# 152/152 [==============================] - 123s 808ms/step - loss: 2.3941 - accuracy: 0.1111 - val_loss: 2.3941 - val_accuracy: 0.1105
# Epoch 10/250
# 152/152 [==============================] - 124s 815ms/step - loss: 2.3941 - accuracy: 0.1102 - val_loss: 2.3942 - val_accuracy: 0.1105
# Epoch 11/250
# 152/152 [==============================] - 121s 797ms/step - loss: 2.3936 - accuracy: 0.1115 - val_loss: 2.3933 - val_accuracy: 0.1076
# Epoch 12/250
# 152/152 [==============================] - 135s 890ms/step - loss: 2.3941 - accuracy: 0.1110 - val_loss: 2.3931 - val_accuracy: 0.1105
# Epoch 13/250
# 152/152 [==============================] - 125s 821ms/step - loss: 2.3937 - accuracy: 0.1119 - val_loss: 2.3935 - val_accuracy: 0.1105
# Epoch 14/250
# 152/152 [==============================] - 123s 804ms/step - loss: 2.3935 - accuracy: 0.1122 - val_loss: 2.3928 - val_accuracy: 0.1103
# Epoch 15/250
# 152/152 [==============================] - 125s 826ms/step - loss: 2.3935 - accuracy: 0.1117 - val_loss: 2.3922 - val_accuracy: 0.1105
# Epoch 16/250
# 152/152 [==============================] - 123s 810ms/step - loss: 2.3938 - accuracy: 0.1125 - val_loss: 2.3920 - val_accuracy: 0.1105
# Epoch 17/250
# 152/152 [==============================] - 123s 809ms/step - loss: 2.3929 - accuracy: 0.1126 - val_loss: 2.3928 - val_accuracy: 0.1105
# Epoch 18/250
# 152/152 [==============================] - 122s 803ms/step - loss: 2.3934 - accuracy: 0.1118 - val_loss: 2.3917 - val_accuracy: 0.1105
# Epoch 19/250
# 152/152 [==============================] - 123s 813ms/step - loss: 2.3933 - accuracy: 0.1122 - val_loss: 2.3923 - val_accuracy: 0.1105
# Epoch 20/250
# 152/152 [==============================] - 124s 815ms/step - loss: 2.3927 - accuracy: 0.1122 - val_loss: 2.3917 - val_accuracy: 0.1105
# Epoch 21/250
# 152/152 [==============================] - 131s 858ms/step - loss: 2.3927 - accuracy: 0.1122 - val_loss: 2.3922 - val_accuracy: 0.1105
# Epoch 22/250
# 152/152 [==============================] - 123s 811ms/step - loss: 2.3927 - accuracy: 0.1122 - val_loss: 2.3928 - val_accuracy: 0.1105
# Epoch 23/250
# 152/152 [==============================] - 123s 810ms/step - loss: 2.3928 - accuracy: 0.1122 - val_loss: 2.3917 - val_accuracy: 0.1105
# Epoch 24/250
# 152/152 [==============================] - 123s 813ms/step - loss: 2.3927 - accuracy: 0.1122 - val_loss: 2.3926 - val_accuracy: 0.1105
# Epoch 25/250
# 152/152 [==============================] - 123s 809ms/step - loss: 2.3926 - accuracy: 0.1122 - val_loss: 2.3921 - val_accuracy: 0.1105
# Epoch 26/250
# 152/152 [==============================] - 123s 813ms/step - loss: 2.3928 - accuracy: 0.1122 - val_loss: 2.3919 - val_accuracy: 0.1105
# Epoch 27/250
# 152/152 [==============================] - 121s 797ms/step - loss: 2.3925 - accuracy: 0.1122 - val_loss: 2.3916 - val_accuracy: 0.1105
# Epoch 28/250
# 152/152 [==============================] - 123s 807ms/step - loss: 2.3925 - accuracy: 0.1122 - val_loss: 2.3925 - val_accuracy: 0.1105
# Epoch 29/250
# 152/152 [==============================] - 122s 801ms/step - loss: 2.3926 - accuracy: 0.1122 - val_loss: 2.3917 - val_accuracy: 0.1105
# Epoch 30/250
# 152/152 [==============================] - 121s 800ms/step - loss: 2.3926 - accuracy: 0.1122 - val_loss: 2.3914 - val_accuracy: 0.1105
# Epoch 31/250
# 152/152 [==============================] - 123s 810ms/step - loss: 2.3926 - accuracy: 0.1122 - val_loss: 2.3916 - val_accuracy: 0.1105
# Epoch 32/250
# 152/152 [==============================] - 134s 880ms/step - loss: 2.3926 - accuracy: 0.1122 - val_loss: 2.3920 - val_accuracy: 0.1105
# Epoch 33/250
# 152/152 [==============================] - 122s 798ms/step - loss: 2.3925 - accuracy: 0.1122 - val_loss: 2.3926 - val_accuracy: 0.1105
# Epoch 34/250
# 152/152 [==============================] - 123s 808ms/step - loss: 2.3927 - accuracy: 0.1122 - val_loss: 2.3920 - val_accuracy: 0.1105
# Epoch 35/250
# 152/152 [==============================] - 121s 796ms/step - loss: 2.3925 - accuracy: 0.1122 - val_loss: 2.3921 - val_accuracy: 0.1105
# Epoch 36/250
# 152/152 [==============================] - 124s 816ms/step - loss: 2.3926 - accuracy: 0.1122 - val_loss: 2.3921 - val_accuracy: 0.1105
# Epoch 37/250
# 152/152 [==============================] - 122s 801ms/step - loss: 2.3926 - accuracy: 0.1122 - val_loss: 2.3923 - val_accuracy: 0.1105
# Epoch 38/250
# 152/152 [==============================] - 124s 819ms/step - loss: 2.3926 - accuracy: 0.1122 - val_loss: 2.3917 - val_accuracy: 0.1105
# Epoch 39/250
# 152/152 [==============================] - 125s 820ms/step - loss: 2.3925 - accuracy: 0.1122 - val_loss: 2.3924 - val_accuracy: 0.1105
# Epoch 40/250
# 152/152 [==============================] - 124s 815ms/step - loss: 2.3924 - accuracy: 0.1122 - val_loss: 2.3920 - val_accuracy: 0.1105
# Epoch 41/250
# 152/152 [==============================] - 125s 826ms/step - loss: 2.3925 - accuracy: 0.1122 - val_loss: 2.3924 - val_accuracy: 0.1105
# Epoch 42/250
# 152/152 [==============================] - 123s 811ms/step - loss: 2.3924 - accuracy: 0.1122 - val_loss: 2.3920 - val_accuracy: 0.1105
# Epoch 43/250
# 152/152 [==============================] - 124s 820ms/step - loss: 2.3924 - accuracy: 0.1122 - val_loss: 2.3921 - val_accuracy: 0.1105
# Epoch 44/250
# 152/152 [==============================] - 124s 819ms/step - loss: 2.3925 - accuracy: 0.1122 - val_loss: 2.3920 - val_accuracy: 0.1105
# Epoch 45/250
# 152/152 [==============================] - 122s 801ms/step - loss: 2.3925 - accuracy: 0.1122 - val_loss: 2.3922 - val_accuracy: 0.1105
# Epoch 46/250
# 152/152 [==============================] - 124s 815ms/step - loss: 2.3924 - accuracy: 0.1122 - val_loss: 2.3918 - val_accuracy: 0.1105
# Epoch 47/250
# 152/152 [==============================] - 122s 803ms/step - loss: 2.3923 - accuracy: 0.1122 - val_loss: 2.3927 - val_accuracy: 0.1105
# Epoch 48/250
# 152/152 [==============================] - 123s 808ms/step - loss: 2.3924 - accuracy: 0.1122 - val_loss: 2.3923 - val_accuracy: 0.1105
# Epoch 49/250
# 152/152 [==============================] - 122s 799ms/step - loss: 2.3924 - accuracy: 0.1122 - val_loss: 2.3921 - val_accuracy: 0.1105
# Epoch 50/250
# 152/152 [==============================] - 124s 814ms/step - loss: 2.3924 - accuracy: 0.1122 - val_loss: 2.3920 - val_accuracy: 0.1105
# Epoch 51/250
# 152/152 [==============================] - 122s 804ms/step - loss: 2.3924 - accuracy: 0.1122 - val_loss: 2.3920 - val_accuracy: 0.1105
# Epoch 52/250
# 152/152 [==============================] - 125s 821ms/step - loss: 2.3924 - accuracy: 0.1122 - val_loss: 2.3916 - val_accuracy: 0.1105
# Epoch 53/250
# 152/152 [==============================] - 122s 804ms/step - loss: 2.3923 - accuracy: 0.1122 - val_loss: 2.3915 - val_accuracy: 0.1105
# Epoch 54/250
# 152/152 [==============================] - 123s 813ms/step - loss: 2.3923 - accuracy: 0.1122 - val_loss: 2.3921 - val_accuracy: 0.1105
# Epoch 55/250
# 152/152 [==============================] - 120s 791ms/step - loss: 2.3922 - accuracy: 0.1122 - val_loss: 2.3926 - val_accuracy: 0.1105
# Epoch 56/250
# 152/152 [==============================] - 123s 812ms/step - loss: 2.3923 - accuracy: 0.1122 - val_loss: 2.3920 - val_accuracy: 0.1105
# Epoch 57/250
# 152/152 [==============================] - 121s 797ms/step - loss: 2.3923 - accuracy: 0.1122 - val_loss: 2.3919 - val_accuracy: 0.1105
# Epoch 58/250
# 152/152 [==============================] - 124s 818ms/step - loss: 2.3923 - accuracy: 0.1122 - val_loss: 2.3924 - val_accuracy: 0.1105
# Epoch 59/250
# 152/152 [==============================] - 122s 801ms/step - loss: 2.3922 - accuracy: 0.1122 - val_loss: 2.3918 - val_accuracy: 0.1105
# Epoch 60/250
# 152/152 [==============================] - 122s 805ms/step - loss: 2.3924 - accuracy: 0.1122 - val_loss: 2.3921 - val_accuracy: 0.1105
# Epoch 61/250
# 152/152 [==============================] - 121s 800ms/step - loss: 2.3923 - accuracy: 0.1122 - val_loss: 2.3922 - val_accuracy: 0.1105
# Epoch 62/250
# 152/152 [==============================] - 123s 808ms/step - loss: 2.3923 - accuracy: 0.1122 - val_loss: 2.3920 - val_accuracy: 0.1105
# Epoch 63/250
# 152/152 [==============================] - 122s 804ms/step - loss: 2.3923 - accuracy: 0.1122 - val_loss: 2.3920 - val_accuracy: 0.1105
# Epoch 64/250
# 152/152 [==============================] - 123s 810ms/step - loss: 2.3923 - accuracy: 0.1122 - val_loss: 2.3918 - val_accuracy: 0.1105
# Epoch 65/250
# 152/152 [==============================] - 124s 815ms/step - loss: 2.3922 - accuracy: 0.1122 - val_loss: 2.3916 - val_accuracy: 0.1105
# Epoch 66/250
# 152/152 [==============================] - 123s 811ms/step - loss: 2.3923 - accuracy: 0.1122 - val_loss: 2.3918 - val_accuracy: 0.1105
# Epoch 67/250
# 152/152 [==============================] - 122s 802ms/step - loss: 2.3922 - accuracy: 0.1122 - val_loss: 2.3919 - val_accuracy: 0.1105
# Epoch 68/250
# 152/152 [==============================] - 133s 877ms/step - loss: 2.3923 - accuracy: 0.1122 - val_loss: 2.3917 - val_accuracy: 0.1105
# Epoch 69/250
# 152/152 [==============================] - 120s 791ms/step - loss: 2.3922 - accuracy: 0.1122 - val_loss: 2.3917 - val_accuracy: 0.1105
# Epoch 70/250
# 152/152 [==============================] - 122s 805ms/step - loss: 2.3922 - accuracy: 0.1122 - val_loss: 2.3917 - val_accuracy: 0.1105
# Epoch 71/250
# 152/152 [==============================] - 122s 798ms/step - loss: 2.3923 - accuracy: 0.1122 - val_loss: 2.3919 - val_accuracy: 0.1105
# Epoch 72/250
# 152/152 [==============================] - 123s 809ms/step - loss: 2.3922 - accuracy: 0.1122 - val_loss: 2.3921 - val_accuracy: 0.1105
# Epoch 73/250
# 152/152 [==============================] - 122s 802ms/step - loss: 2.3922 - accuracy: 0.1122 - val_loss: 2.3920 - val_accuracy: 0.1105
# Epoch 74/250
# 152/152 [==============================] - 124s 814ms/step - loss: 2.3922 - accuracy: 0.1122 - val_loss: 2.3920 - val_accuracy: 0.1105
# Epoch 75/250
# 152/152 [==============================] - 123s 810ms/step - loss: 2.3922 - accuracy: 0.1122 - val_loss: 2.3920 - val_accuracy: 0.1105
# Epoch 76/250
# 152/152 [==============================] - 123s 808ms/step - loss: 2.3922 - accuracy: 0.1122 - val_loss: 2.3918 - val_accuracy: 0.1105
# Epoch 77/250
# 152/152 [==============================] - 121s 799ms/step - loss: 2.3922 - accuracy: 0.1122 - val_loss: 2.3921 - val_accuracy: 0.1105
# Epoch 78/250
# 152/152 [==============================] - 133s 877ms/step - loss: 2.3922 - accuracy: 0.1122 - val_loss: 2.3921 - val_accuracy: 0.1105
# Epoch 79/250
# 152/152 [==============================] - 123s 806ms/step - loss: 2.3922 - accuracy: 0.1122 - val_loss: 2.3921 - val_accuracy: 0.1105
# Epoch 80/250
# 152/152 [==============================] - 122s 804ms/step - loss: 2.3922 - accuracy: 0.1122 - val_loss: 2.3920 - val_accuracy: 0.1105
# Epoch 81/250
# 152/152 [==============================] - 122s 801ms/step - loss: 2.3922 - accuracy: 0.1122 - val_loss: 2.3919 - val_accuracy: 0.1105
# Epoch 82/250
# 152/152 [==============================] - 122s 807ms/step - loss: 2.3922 - accuracy: 0.1122 - val_loss: 2.3918 - val_accuracy: 0.1105
# Epoch 83/250
# 152/152 [==============================] - 121s 795ms/step - loss: 2.3922 - accuracy: 0.1122 - val_loss: 2.3918 - val_accuracy: 0.1105
# Epoch 84/250
# 152/152 [==============================] - 120s 792ms/step - loss: 2.3922 - accuracy: 0.1122 - val_loss: 2.3919 - val_accuracy: 0.1105
# Epoch 85/250
# 152/152 [==============================] - 122s 799ms/step - loss: 2.3922 - accuracy: 0.1122 - val_loss: 2.3919 - val_accuracy: 0.1105
# Epoch 86/250
# 152/152 [==============================] - 121s 796ms/step - loss: 2.3922 - accuracy: 0.1122 - val_loss: 2.3918 - val_accuracy: 0.1105
# Epoch 87/250
# 152/152 [==============================] - 123s 808ms/step - loss: 2.3922 - accuracy: 0.1122 - val_loss: 2.3919 - val_accuracy: 0.1105
# Epoch 88/250
# 152/152 [==============================] - 121s 799ms/step - loss: 2.3921 - accuracy: 0.1122 - val_loss: 2.3919 - val_accuracy: 0.1105
# Epoch 89/250
# 152/152 [==============================] - 133s 879ms/step - loss: 2.3922 - accuracy: 0.1122 - val_loss: 2.3921 - val_accuracy: 0.1105
# Epoch 90/250
# 152/152 [==============================] - 123s 807ms/step - loss: 2.3921 - accuracy: 0.1122 - val_loss: 2.3917 - val_accuracy: 0.1105
# Epoch 91/250
# 152/152 [==============================] - 124s 814ms/step - loss: 2.3921 - accuracy: 0.1122 - val_loss: 2.3919 - val_accuracy: 0.1105
# Epoch 92/250
# 152/152 [==============================] - 121s 796ms/step - loss: 2.3922 - accuracy: 0.1122 - val_loss: 2.3918 - val_accuracy: 0.1105
# Epoch 93/250
# 152/152 [==============================] - 124s 816ms/step - loss: 2.3921 - accuracy: 0.1122 - val_loss: 2.3918 - val_accuracy: 0.1105
# Epoch 94/250
# 152/152 [==============================] - 122s 802ms/step - loss: 2.3921 - accuracy: 0.1122 - val_loss: 2.3918 - val_accuracy: 0.1105
# Epoch 95/250
# 152/152 [==============================] - 122s 803ms/step - loss: 2.3921 - accuracy: 0.1122 - val_loss: 2.3919 - val_accuracy: 0.1105
# Epoch 96/250
# 152/152 [==============================] - 124s 812ms/step - loss: 2.3921 - accuracy: 0.1122 - val_loss: 2.3919 - val_accuracy: 0.1105
# Epoch 97/250
# 152/152 [==============================] - 134s 882ms/step - loss: 2.3921 - accuracy: 0.1122 - val_loss: 2.3919 - val_accuracy: 0.1105
# Epoch 98/250
# 152/152 [==============================] - 122s 800ms/step - loss: 2.3921 - accuracy: 0.1122 - val_loss: 2.3918 - val_accuracy: 0.1105
# Epoch 99/250
# 152/152 [==============================] - 123s 811ms/step - loss: 2.3922 - accuracy: 0.1122 - val_loss: 2.3918 - val_accuracy: 0.1105
# Epoch 100/250
# 152/152 [==============================] - 125s 820ms/step - loss: 2.3922 - accuracy: 0.1122 - val_loss: 2.3917 - val_accuracy: 0.1105
# Epoch 101/250
# 152/152 [==============================] - 123s 809ms/step - loss: 2.3921 - accuracy: 0.1122 - val_loss: 2.3917 - val_accuracy: 0.1105
# Epoch 102/250
# 152/152 [==============================] - 124s 815ms/step - loss: 2.3921 - accuracy: 0.1122 - val_loss: 2.3917 - val_accuracy: 0.1105
# Epoch 103/250
# 152/152 [==============================] - 123s 809ms/step - loss: 2.3922 - accuracy: 0.1122 - val_loss: 2.3918 - val_accuracy: 0.1105
# Epoch 104/250
# 152/152 [==============================] - 122s 803ms/step - loss: 2.3921 - accuracy: 0.1122 - val_loss: 2.3917 - val_accuracy: 0.1105
# Epoch 105/250
# 152/152 [==============================] - 132s 867ms/step - loss: 2.3921 - accuracy: 0.1122 - val_loss: 2.3918 - val_accuracy: 0.1105
# Epoch 106/250
# 152/152 [==============================] - 121s 796ms/step - loss: 2.3921 - accuracy: 0.1122 - val_loss: 2.3919 - val_accuracy: 0.1105
# Epoch 107/250
# 152/152 [==============================] - 123s 810ms/step - loss: 2.3921 - accuracy: 0.1122 - val_loss: 2.3919 - val_accuracy: 0.1105
# Epoch 108/250
# 152/152 [==============================] - 123s 808ms/step - loss: 2.3921 - accuracy: 0.1122 - val_loss: 2.3918 - val_accuracy: 0.1105
# Epoch 109/250
# 152/152 [==============================] - 123s 810ms/step - loss: 2.3921 - accuracy: 0.1122 - val_loss: 2.3921 - val_accuracy: 0.1105
# Epoch 110/250
# 152/152 [==============================] - 121s 799ms/step - loss: 2.3921 - accuracy: 0.1122 - val_loss: 2.3921 - val_accuracy: 0.1105
# Epoch 111/250
# 152/152 [==============================] - 123s 808ms/step - loss: 2.3921 - accuracy: 0.1122 - val_loss: 2.3919 - val_accuracy: 0.1105
# Epoch 112/250
# 152/152 [==============================] - 123s 809ms/step - loss: 2.3921 - accuracy: 0.1122 - val_loss: 2.3919 - val_accuracy: 0.1105
# Epoch 113/250
# 152/152 [==============================] - 123s 812ms/step - loss: 2.3921 - accuracy: 0.1122 - val_loss: 2.3919 - val_accuracy: 0.1105
# Epoch 114/250
# 152/152 [==============================] - 125s 825ms/step - loss: 2.3921 - accuracy: 0.1122 - val_loss: 2.3919 - val_accuracy: 0.1105
# Epoch 115/250
# 152/152 [==============================] - 122s 801ms/step - loss: 2.3921 - accuracy: 0.1122 - val_loss: 2.3921 - val_accuracy: 0.1105
# Epoch 116/250
# 152/152 [==============================] - 125s 822ms/step - loss: 2.3921 - accuracy: 0.1122 - val_loss: 2.3918 - val_accuracy: 0.1105
# Epoch 117/250
# 152/152 [==============================] - 122s 805ms/step - loss: 2.3921 - accuracy: 0.1122 - val_loss: 2.3919 - val_accuracy: 0.1105
# Epoch 118/250
# 152/152 [==============================] - 124s 813ms/step - loss: 2.3920 - accuracy: 0.1122 - val_loss: 2.3918 - val_accuracy: 0.1105
# Epoch 119/250
# 152/152 [==============================] - 124s 816ms/step - loss: 2.3921 - accuracy: 0.1122 - val_loss: 2.3918 - val_accuracy: 0.1105
# Epoch 120/250
# 152/152 [==============================] - 124s 817ms/step - loss: 2.3921 - accuracy: 0.1122 - val_loss: 2.3918 - val_accuracy: 0.1105
# Epoch 121/250
# 152/152 [==============================] - 123s 811ms/step - loss: 2.3921 - accuracy: 0.1122 - val_loss: 2.3919 - val_accuracy: 0.1105
# Epoch 122/250
# 152/152 [==============================] - 123s 805ms/step - loss: 2.3921 - accuracy: 0.1122 - val_loss: 2.3918 - val_accuracy: 0.1105
# Epoch 123/250
# 152/152 [==============================] - 123s 812ms/step - loss: 2.3921 - accuracy: 0.1122 - val_loss: 2.3919 - val_accuracy: 0.1105
# Epoch 124/250
# 152/152 [==============================] - 122s 799ms/step - loss: 2.3921 - accuracy: 0.1122 - val_loss: 2.3918 - val_accuracy: 0.1105
# Epoch 125/250
# 152/152 [==============================] - 124s 820ms/step - loss: 2.3921 - accuracy: 0.1122 - val_loss: 2.3917 - val_accuracy: 0.1105
# Epoch 126/250
# 152/152 [==============================] - 123s 812ms/step - loss: 2.3921 - accuracy: 0.1122 - val_loss: 2.3918 - val_accuracy: 0.1105
# Epoch 127/250
# 152/152 [==============================] - 124s 814ms/step - loss: 2.3921 - accuracy: 0.1122 - val_loss: 2.3919 - val_accuracy: 0.1105
# Epoch 128/250
# 152/152 [==============================] - 121s 798ms/step - loss: 2.3920 - accuracy: 0.1122 - val_loss: 2.3918 - val_accuracy: 0.1105
# Epoch 129/250
# 152/152 [==============================] - 135s 887ms/step - loss: 2.3921 - accuracy: 0.1122 - val_loss: 2.3919 - val_accuracy: 0.1105
# Epoch 130/250
# 152/152 [==============================] - 122s 804ms/step - loss: 2.3921 - accuracy: 0.1122 - val_loss: 2.3919 - val_accuracy: 0.1105
# Epoch 131/250
# 152/152 [==============================] - 124s 819ms/step - loss: 2.3921 - accuracy: 0.1122 - val_loss: 2.3919 - val_accuracy: 0.1105
# Epoch 132/250
# 152/152 [==============================] - 124s 818ms/step - loss: 2.3921 - accuracy: 0.1122 - val_loss: 2.3918 - val_accuracy: 0.1105
# Epoch 133/250
# 152/152 [==============================] - 122s 799ms/step - loss: 2.3921 - accuracy: 0.1122 - val_loss: 2.3918 - val_accuracy: 0.1105
# Epoch 134/250
# 152/152 [==============================] - 123s 811ms/step - loss: 2.3921 - accuracy: 0.1122 - val_loss: 2.3919 - val_accuracy: 0.1105
# Epoch 135/250
# 152/152 [==============================] - 122s 802ms/step - loss: 2.3920 - accuracy: 0.1122 - val_loss: 2.3918 - val_accuracy: 0.1105
# Epoch 136/250
# 152/152 [==============================] - 124s 816ms/step - loss: 2.3920 - accuracy: 0.1122 - val_loss: 2.3919 - val_accuracy: 0.1105
# Epoch 137/250
# 152/152 [==============================] - 122s 805ms/step - loss: 2.3921 - accuracy: 0.1122 - val_loss: 2.3918 - val_accuracy: 0.1105
# Epoch 138/250
# 152/152 [==============================] - 123s 810ms/step - loss: 2.3920 - accuracy: 0.1122 - val_loss: 2.3918 - val_accuracy: 0.1105
# Epoch 139/250
# 152/152 [==============================] - 123s 808ms/step - loss: 2.3920 - accuracy: 0.1122 - val_loss: 2.3918 - val_accuracy: 0.1105
# Epoch 140/250
# 152/152 [==============================] - 123s 810ms/step - loss: 2.3920 - accuracy: 0.1122 - val_loss: 2.3918 - val_accuracy: 0.1105
# Epoch 141/250
# 152/152 [==============================] - 127s 839ms/step - loss: 2.3920 - accuracy: 0.1122 - val_loss: 2.3919 - val_accuracy: 0.1105
# Epoch 142/250
# 152/152 [==============================] - 128s 842ms/step - loss: 2.3921 - accuracy: 0.1122 - val_loss: 2.3919 - val_accuracy: 0.1105
# Epoch 143/250
# 152/152 [==============================] - 139s 913ms/step - loss: 2.3921 - accuracy: 0.1122 - val_loss: 2.3919 - val_accuracy: 0.1105
# Epoch 144/250
# 152/152 [==============================] - 128s 840ms/step - loss: 2.3921 - accuracy: 0.1122 - val_loss: 2.3919 - val_accuracy: 0.1105
# Epoch 145/250
# 152/152 [==============================] - 129s 848ms/step - loss: 2.3921 - accuracy: 0.1122 - val_loss: 2.3919 - val_accuracy: 0.1105
# Epoch 146/250
# 152/152 [==============================] - 123s 806ms/step - loss: 2.3920 - accuracy: 0.1122 - val_loss: 2.3919 - val_accuracy: 0.1105
# Epoch 147/250
# 152/152 [==============================] - 122s 802ms/step - loss: 2.3920 - accuracy: 0.1122 - val_loss: 2.3919 - val_accuracy: 0.1105
# Epoch 148/250
# 152/152 [==============================] - 124s 814ms/step - loss: 2.3920 - accuracy: 0.1122 - val_loss: 2.3918 - val_accuracy: 0.1105
# Epoch 149/250
# 152/152 [==============================] - 123s 806ms/step - loss: 2.3920 - accuracy: 0.1122 - val_loss: 2.3919 - val_accuracy: 0.1105
# Epoch 150/250
# 152/152 [==============================] - 122s 804ms/step - loss: 2.3921 - accuracy: 0.1122 - val_loss: 2.3919 - val_accuracy: 0.1105
# Epoch 151/250
# 152/152 [==============================] - 123s 804ms/step - loss: 2.3920 - accuracy: 0.1122 - val_loss: 2.3918 - val_accuracy: 0.1105
# Epoch 152/250
# 152/152 [==============================] - 123s 813ms/step - loss: 2.3920 - accuracy: 0.1122 - val_loss: 2.3918 - val_accuracy: 0.1105
# Epoch 153/250
# 152/152 [==============================] - 120s 787ms/step - loss: 2.3920 - accuracy: 0.1122 - val_loss: 2.3919 - val_accuracy: 0.1105
# Epoch 154/250
# 152/152 [==============================] - 123s 811ms/step - loss: 2.3921 - accuracy: 0.1122 - val_loss: 2.3919 - val_accuracy: 0.1105
# Epoch 155/250
# 152/152 [==============================] - 122s 804ms/step - loss: 2.3920 - accuracy: 0.1122 - val_loss: 2.3918 - val_accuracy: 0.1105
# Epoch 156/250
# 152/152 [==============================] - 123s 811ms/step - loss: 2.3921 - accuracy: 0.1122 - val_loss: 2.3919 - val_accuracy: 0.1105
# Epoch 157/250
# 152/152 [==============================] - 121s 798ms/step - loss: 2.3921 - accuracy: 0.1122 - val_loss: 2.3918 - val_accuracy: 0.1105
# Epoch 158/250
# 152/152 [==============================] - 124s 819ms/step - loss: 2.3921 - accuracy: 0.1122 - val_loss: 2.3918 - val_accuracy: 0.1105
# Epoch 159/250
# 152/152 [==============================] - 121s 798ms/step - loss: 2.3920 - accuracy: 0.1122 - val_loss: 2.3918 - val_accuracy: 0.1105
# Epoch 160/250
# 152/152 [==============================] - 123s 812ms/step - loss: 2.3920 - accuracy: 0.1122 - val_loss: 2.3918 - val_accuracy: 0.1105
# Epoch 161/250
# 152/152 [==============================] - 122s 802ms/step - loss: 2.3920 - accuracy: 0.1122 - val_loss: 2.3919 - val_accuracy: 0.1105
# Epoch 162/250
# 152/152 [==============================] - 123s 812ms/step - loss: 2.3920 - accuracy: 0.1122 - val_loss: 2.3919 - val_accuracy: 0.1105
# Epoch 163/250
# 152/152 [==============================] - 121s 794ms/step - loss: 2.3920 - accuracy: 0.1122 - val_loss: 2.3918 - val_accuracy: 0.1105
# Epoch 164/250
# 152/152 [==============================] - 123s 810ms/step - loss: 2.3921 - accuracy: 0.1122 - val_loss: 2.3918 - val_accuracy: 0.1105
# Epoch 165/250
# 152/152 [==============================] - 122s 799ms/step - loss: 2.3920 - accuracy: 0.1122 - val_loss: 2.3918 - val_accuracy: 0.1105
# Epoch 166/250
# 152/152 [==============================] - 123s 809ms/step - loss: 2.3920 - accuracy: 0.1122 - val_loss: 2.3917 - val_accuracy: 0.1105
# Epoch 167/250
# 152/152 [==============================] - 122s 801ms/step - loss: 2.3920 - accuracy: 0.1122 - val_loss: 2.3918 - val_accuracy: 0.1105
# Epoch 168/250
# 152/152 [==============================] - 124s 814ms/step - loss: 2.3920 - accuracy: 0.1122 - val_loss: 2.3919 - val_accuracy: 0.1105
# Epoch 169/250
# 152/152 [==============================] - 123s 811ms/step - loss: 2.3920 - accuracy: 0.1122 - val_loss: 2.3919 - val_accuracy: 0.1105
# Epoch 170/250
# 152/152 [==============================] - 123s 807ms/step - loss: 2.3920 - accuracy: 0.1122 - val_loss: 2.3919 - val_accuracy: 0.1105
# Epoch 171/250
# 152/152 [==============================] - 125s 823ms/step - loss: 2.3920 - accuracy: 0.1122 - val_loss: 2.3918 - val_accuracy: 0.1105
# Epoch 172/250
# 152/152 [==============================] - 124s 810ms/step - loss: 2.3920 - accuracy: 0.1122 - val_loss: 2.3918 - val_accuracy: 0.1105
# Epoch 173/250
# 152/152 [==============================] - 123s 810ms/step - loss: 2.3920 - accuracy: 0.1122 - val_loss: 2.3918 - val_accuracy: 0.1105
# Epoch 174/250
# 152/152 [==============================] - 122s 798ms/step - loss: 2.3920 - accuracy: 0.1122 - val_loss: 2.3918 - val_accuracy: 0.1105
# Epoch 175/250
# 152/152 [==============================] - 123s 809ms/step - loss: 2.3920 - accuracy: 0.1122 - val_loss: 2.3918 - val_accuracy: 0.1105
# Epoch 176/250
# 152/152 [==============================] - 131s 863ms/step - loss: 2.3920 - accuracy: 0.1122 - val_loss: 2.3919 - val_accuracy: 0.1105
# Epoch 177/250
# 152/152 [==============================] - 124s 818ms/step - loss: 2.3920 - accuracy: 0.1122 - val_loss: 2.3918 - val_accuracy: 0.1105
# Epoch 178/250
# 152/152 [==============================] - 124s 813ms/step - loss: 2.3920 - accuracy: 0.1122 - val_loss: 2.3919 - val_accuracy: 0.1105
# Epoch 179/250
# 152/152 [==============================] - 123s 810ms/step - loss: 2.3920 - accuracy: 0.1122 - val_loss: 2.3919 - val_accuracy: 0.1105
# Epoch 180/250
# 152/152 [==============================] - 125s 820ms/step - loss: 2.3920 - accuracy: 0.1122 - val_loss: 2.3918 - val_accuracy: 0.1105
# Epoch 181/250
# 152/152 [==============================] - 123s 807ms/step - loss: 2.3920 - accuracy: 0.1122 - val_loss: 2.3918 - val_accuracy: 0.1105
# Epoch 182/250
# 152/152 [==============================] - 121s 795ms/step - loss: 2.3920 - accuracy: 0.1122 - val_loss: 2.3918 - val_accuracy: 0.1105
# Epoch 183/250
# 152/152 [==============================] - 134s 881ms/step - loss: 2.3920 - accuracy: 0.1122 - val_loss: 2.3918 - val_accuracy: 0.1105
# Epoch 184/250
# 152/152 [==============================] - 122s 803ms/step - loss: 2.3920 - accuracy: 0.1122 - val_loss: 2.3917 - val_accuracy: 0.1105
# Epoch 185/250
# 152/152 [==============================] - 123s 812ms/step - loss: 2.3920 - accuracy: 0.1122 - val_loss: 2.3917 - val_accuracy: 0.1105
# Epoch 186/250
# 152/152 [==============================] - 123s 806ms/step - loss: 2.3920 - accuracy: 0.1122 - val_loss: 2.3918 - val_accuracy: 0.1105
# Epoch 187/250
# 152/152 [==============================] - 124s 818ms/step - loss: 2.3920 - accuracy: 0.1122 - val_loss: 2.3918 - val_accuracy: 0.1105
# Epoch 188/250
# 152/152 [==============================] - 121s 796ms/step - loss: 2.3920 - accuracy: 0.1122 - val_loss: 2.3918 - val_accuracy: 0.1105
# Epoch 189/250
# 152/152 [==============================] - 124s 816ms/step - loss: 2.3920 - accuracy: 0.1122 - val_loss: 2.3918 - val_accuracy: 0.1105
# Epoch 190/250
# 152/152 [==============================] - 122s 802ms/step - loss: 2.3920 - accuracy: 0.1122 - val_loss: 2.3918 - val_accuracy: 0.1105
# Epoch 191/250
# 152/152 [==============================] - 121s 798ms/step - loss: 2.3920 - accuracy: 0.1122 - val_loss: 2.3918 - val_accuracy: 0.1105
# Epoch 192/250
# 152/152 [==============================] - 133s 876ms/step - loss: 2.3920 - accuracy: 0.1122 - val_loss: 2.3918 - val_accuracy: 0.1105
# Epoch 193/250
# 152/152 [==============================] - 124s 818ms/step - loss: 2.3920 - accuracy: 0.1122 - val_loss: 2.3918 - val_accuracy: 0.1105
# Epoch 194/250
# 152/152 [==============================] - 132s 870ms/step - loss: 2.3920 - accuracy: 0.1122 - val_loss: 2.3918 - val_accuracy: 0.1105
# Epoch 195/250
# 152/152 [==============================] - 124s 817ms/step - loss: 2.3920 - accuracy: 0.1122 - val_loss: 2.3918 - val_accuracy: 0.1105
# Epoch 196/250
# 152/152 [==============================] - 122s 801ms/step - loss: 2.3920 - accuracy: 0.1122 - val_loss: 2.3919 - val_accuracy: 0.1105
# Epoch 197/250
# 106/152 [===================>..........] - ETA: 33s - loss: 2.3921 - accuracy: 0.1124
