# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
from collections import deque
import random
import matplotlib.pyplot as plt

class DQNAgent:
    def __init__(self, n_states, n_actions, learning_rate=0.001, gamma=0.99, epsilon=1.0, buffer_size=10000):
        self.n_states = n_states
        self.n_actions = n_actions
        self.learning_rate = learning_rate
        self.gamma = gamma
        self.epsilon = epsilon
        self.epsilon_min = 0.01
        self.epsilon_decay = 0.995
        self.memory = deque(maxlen=buffer_size)

        self.model = self.build_model()

    def build_model(self):
        model = tf.keras.Sequential([
            tf.keras.layers.Dense(256, input_dim=self.n_states, activation='relu'),
            tf.keras.layers.Dropout(0.2),
            tf.keras.layers.Dense(256, activation='relu'),
            tf.keras.layers.Dropout(0.2),
            tf.keras.layers.Dense(self.n_actions, activation='linear')
        ])
        model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=self.learning_rate), loss='mse')
        return model

    def get_action(self, state):
        if np.random.rand() <= self.epsilon:
            return np.random.choice(self.n_actions)
        q_values = self.model.predict(state.reshape(1, -1), batch_size=1, verbose=0)
        return np.argmax(q_values[0])

    def remember(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))

    def replay(self, batch_size):
        if len(self.memory) < batch_size:
            return
        minibatch = random.sample(self.memory, batch_size)
        for state, action, reward, next_state, done in minibatch:
            target = reward
            if not done:
                target = (reward + self.gamma *
                          np.amax(self.model.predict(next_state.reshape(1, -1), batch_size=1, verbose=0)[0]))
            target_f = self.model.predict(state.reshape(1, -1), batch_size=1, verbose=0)
            target_f[0][action] = target
            self.model.fit(state.reshape(1, -1), target_f, epochs=1, verbose=0)
        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay

def calculate_reward(action, acerto):
    if action == 1:
        if acerto == 1:
            return 10
        elif acerto == 2:
            return -5
    return 0

def normalize_data(features):
    scaler = StandardScaler()
    return scaler.fit_transform(features)

def main():
    data = pd.read_csv('/home/darkcover/Documentos/Out/dados/data_final.csv')
    features = data[['odd_entrada', 'media5', 'media10', 'media20', 'media40', 'media80', 'media160', 'media320', 'media640', 'level', 'contagem']].values
    rewards = data['apostar'].values
    features = normalize_data(features)

    X_train, X_test, y_train, y_test = train_test_split(features, rewards, test_size=0.2, random_state=42)

    n_epochs = 25
    batch_size = 128

    n_states = X_train.shape[1]
    n_actions = 2
    dqn_agent = DQNAgent(n_states, n_actions)

    epoch_accuracies = []
    epoch_directional_accuracies = []
    epoch_weighted_directional_accuracies = []

    for epoch in range(n_epochs):
        correct_predictions = 0
        overestimations = 0
        weighted_correct_predictions = 0
        weighted_overestimations = 0

        for i in range(len(X_train) - 1):
            state = X_train[i]
            action = dqn_agent.get_action(state)
            true_action = y_train[i]
            acerto = state[-3]
            reward = calculate_reward(action, acerto)
            next_state = X_train[i + 1]
            done = (i == len(X_train) - 2)

            dqn_agent.remember(state, action, reward, next_state, done)
            if done:
                dqn_agent.replay(batch_size)

            if action == true_action:
                correct_predictions += 1
                weighted_correct_predictions += 2
            elif action > true_action:
                overestimations += 1
                weighted_overestimations += 1

        epoch_accuracy = correct_predictions / len(X_test)
        epoch_directional_accuracy = (correct_predictions + overestimations) / len(X_test)
        epoch_weighted_directional_accuracy = (weighted_correct_predictions + weighted_overestimations) / len(X_test)

        epoch_accuracies.append(epoch_accuracy)
        epoch_directional_accuracies.append(epoch_directional_accuracy)
        epoch_weighted_directional_accuracies.append(epoch_weighted_directional_accuracy)

        print(f'Época {epoch + 1}/{n_epochs} - Precisão: {epoch_accuracy:.4f}, Acurácia Direcional: {epoch_directional_accuracy:.4f}, Acurácia Direcional Ponderada: {epoch_weighted_directional_accuracy:.4f}')

    plt.figure(figsize=(12, 6))
    plt.plot(epoch_accuracies, label='Precisão')
    plt.plot(epoch_directional_accuracies, label='Acurácia Direcional')
    plt.plot(epoch_weighted_directional_accuracies, label='Acurácia Direcional Ponderada')
    plt.xlabel('Época')
    plt.ylabel('Métrica')
    plt.legend()
    plt.title('Desempenho do Modelo ao Longo das Épocas')
    plt.show()

if __name__ == "__main__":
    main()
# Out:
# /home/darkcover/Documentos/Out/venv/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Época 1/25 - Precisão: 1.9994, Acurácia Direcional: 3.9621, Acurácia Direcional Ponderada: 5.9615
# Época 2/25 - Precisão: 2.0150, Acurácia Direcional: 3.9609, Acurácia Direcional Ponderada: 5.9759
# Época 3/25 - Precisão: 2.0233, Acurácia Direcional: 3.9611, Acurácia Direcional Ponderada: 5.9844
# Época 4/25 - Precisão: 2.0295, Acurácia Direcional: 3.9611, Acurácia Direcional Ponderada: 5.9905
# Época 5/25 - Precisão: 1.9912, Acurácia Direcional: 3.9622, Acurácia Direcional Ponderada: 5.9534
# Época 6/25 - Precisão: 1.9535, Acurácia Direcional: 3.9625, Acurácia Direcional Ponderada: 5.9160
# Época 7/25 - Precisão: 2.0324, Acurácia Direcional: 3.9607, Acurácia Direcional Ponderada: 5.9931
# Época 8/25 - Precisão: 2.0586, Acurácia Direcional: 3.9618, Acurácia Direcional Ponderada: 6.0203
# Época 9/25 - Precisão: 2.0343, Acurácia Direcional: 3.9627, Acurácia Direcional Ponderada: 5.9970
# Época 10/25 - Precisão: 2.0187, Acurácia Direcional: 3.9617, Acurácia Direcional Ponderada: 5.9803
# Época 11/25 - Precisão: 1.9804, Acurácia Direcional: 3.9625, Acurácia Direcional Ponderada: 5.9429
# Época 12/25 - Precisão: 2.0890, Acurácia Direcional: 3.9607, Acurácia Direcional Ponderada: 6.0498
# Época 13/25 - Precisão: 2.0783, Acurácia Direcional: 3.9601, Acurácia Direcional Ponderada: 6.0385
# Época 14/25 - Precisão: 1.9994, Acurácia Direcional: 3.9602, Acurácia Direcional Ponderada: 5.9596
# Época 15/25 - Precisão: 2.0696, Acurácia Direcional: 3.9592, Acurácia Direcional Ponderada: 6.0287
# Época 16/25 - Precisão: 1.9789, Acurácia Direcional: 3.9607, Acurácia Direcional Ponderada: 5.9396
# Época 17/25 - Precisão: 2.0292, Acurácia Direcional: 3.9593, Acurácia Direcional Ponderada: 5.9884
# Época 18/25 - Precisão: 1.9969, Acurácia Direcional: 3.9596, Acurácia Direcional Ponderada: 5.9565
# Época 19/25 - Precisão: 2.1518, Acurácia Direcional: 3.9578, Acurácia Direcional Ponderada: 6.1096
# Época 20/25 - Precisão: 2.0976, Acurácia Direcional: 3.9576, Acurácia Direcional Ponderada: 6.0552
# Época 21/25 - Precisão: 2.0118, Acurácia Direcional: 3.9606, Acurácia Direcional Ponderada: 5.9724
# Época 22/25 - Precisão: 1.9897, Acurácia Direcional: 3.9601, Acurácia Direcional Ponderada: 5.9497
# Época 23/25 - Precisão: 1.8337, Acurácia Direcional: 3.9606, Acurácia Direcional Ponderada: 5.7942
# 2024-06-09 14:12:03.515454: W tensorflow/core/data/root_dataset.cc:350] Optimization loop failed: CANCELLED: Operation was cancelled
# Época 24/25 - Precisão: 1.9445, Acurácia Direcional: 3.9613, Acurácia Direcional Ponderada: 5.9058
# Época 25/25 - Precisão: 2.1103, Acurácia Direcional: 3.9573, Acurácia Direcional Ponderada: 6.0676

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
from collections import deque
import random
import matplotlib.pyplot as plt

class DQNAgent:
    def __init__(self, n_states, n_actions, learning_rate, gamma, epsilon, epsilon_decay, epsilon_min, buffer_size=10000):
        self.n_states = n_states
        self.n_actions = n_actions
        self.learning_rate = learning_rate
        self.gamma = gamma
        self.epsilon = epsilon
        self.epsilon_decay = epsilon_decay
        self.epsilon_min = epsilon_min
        self.memory = deque(maxlen=buffer_size)
        self.model = self.build_model()
        self.model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate), loss=tf.keras.losses.Huber())

    def build_model(self):
        model = tf.keras.Sequential([
            tf.keras.layers.Input(shape=(self.n_states,)),
            tf.keras.layers.Dense(256, activation='relu'),
            tf.keras.layers.BatchNormalization(),
            tf.keras.layers.Dropout(0.2),
            tf.keras.layers.Dense(256, activation='relu'),
            tf.keras.layers.BatchNormalization(),
            tf.keras.layers.Dropout(0.2),
            tf.keras.layers.Dense(self.n_actions, activation='linear')
        ])
        return model

    def get_action(self, state):
        if np.random.random() < self.epsilon:
            return np.random.choice(self.n_actions)
        else:
            q_values = self.model.predict(state.reshape(1, -1), batch_size=1, verbose=0)
            return np.argmax(q_values)

    def remember(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))

    def replay(self, batch_size):
        if len(self.memory) < batch_size:
            return
        minibatch = random.sample(self.memory, batch_size)
        for state, action, reward, next_state, done in minibatch:
            target = reward
            if not done:
                target = reward + self.gamma * np.amax(self.model.predict(next_state.reshape(1, -1), batch_size=1, verbose=0))
            target_f = self.model.predict(state.reshape(1, -1), batch_size=1, verbose=0)
            target_f[0][action] = target
            self.model.fit(state.reshape(1, -1), target_f, epochs=1, verbose=0)

    def update_epsilon(self):
        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay

def calculate_reward(action, acerto):
    reward = 0
    if action == 1:  # Apostou
        if acerto == 1:
            reward = 1  # Recompensa por apostar corretamente
        elif acerto == 2:
            reward = -1  # Penalidade por apostar incorretamente
    return reward

def normalize_data(features):
    scaler = StandardScaler()
    return scaler.fit_transform(features)

def main():
    # Carregar os dados
    data = pd.read_csv('/home/darkcover/Documentos/Out/dados/data_final.csv')

    # Selecionar as features e a variável de saída
    features = data[['odd_entrada', 'media5', 'media10', 'media20', 'media40', 'media80', 'media160', 'media320', 'media640']].values
    actions = data['apostar'].values  # Variável de saída: se deve apostar ou não
    acertos = data[['acerto', 'level', 'contagem']].values  # Variável de saída para calcular a recompensa

    features = normalize_data(features)

    # Adicionar level e contagem às features
    features = np.hstack((features, acertos[:, 1:]))

    # Dividir os dados em treino e teste
    X_train, X_test, y_train, y_test, acerto_train, acerto_test = train_test_split(features, actions, acertos, test_size=0.2, random_state=42)

    # Parâmetros de treinamento
    n_epochs = 10
    batch_size = 128

    # Crie o agente DQN
    n_states = X_train.shape[1]
    n_actions = 2  # Ações possíveis: apostar ou não apostar
    dqn_agent = DQNAgent(n_states, n_actions, learning_rate=0.001, gamma=0.99, epsilon=1.0, epsilon_decay=0.99, epsilon_min=0.01, buffer_size=10000)

    epoch_accuracies = []
    epoch_directional_accuracies = []
    epoch_weighted_directional_accuracies = []

    # Treinamento do agente
    for epoch in range(n_epochs):
        correct_predictions = 0
        overestimations = 0
        weighted_correct_predictions = 0
        weighted_overestimations = 0

        for i in range(len(X_train) - 1):
            state = X_train[i, :]
            action = dqn_agent.get_action(state)
            true_action = y_train[i]
            acerto = acerto_train[i][0]
            reward = calculate_reward(action, acerto)
            next_state = X_train[i + 1, :]
            done = (i == len(X_train) - 2)

            dqn_agent.remember(state, action, reward, next_state, done)

            if done:
                dqn_agent.replay(batch_size)
                dqn_agent.update_epsilon()

            if action == true_action:
                correct_predictions += 1
                weighted_correct_predictions += 2  # Peso maior para acertos exatos
            elif action > true_action:
                overestimations += 1
                weighted_overestimations += 1  # Peso menor para erros

        epoch_accuracy = correct_predictions / len(X_test)
        epoch_directional_accuracy = (correct_predictions + overestimations) / len(X_test)
        epoch_weighted_directional_accuracy = (weighted_correct_predictions + weighted_overestimations) / len(X_test)

        epoch_accuracies.append(epoch_accuracy)
        epoch_directional_accuracies.append(epoch_directional_accuracy)
        epoch_weighted_directional_accuracies.append(epoch_weighted_directional_accuracy)

        print(f'Época {epoch + 1}/{n_epochs} - Precisão: {epoch_accuracy:.4f}, Acurácia Direcional: {epoch_directional_accuracy:.4f}, Acurácia Direcional Ponderada: {epoch_weighted_directional_accuracy:.4f}')

    # Teste o agente
    correct_predictions = 0
    overestimations = 0
    weighted_correct_predictions = 0
    weighted_overestimations = 0

    predicted_actions = []

    for i in range(len(X_test)):
        state = X_test[i, :]
        action = dqn_agent.get_action(state)
        true_action = y_test[i]

        predicted_actions.append(action)

        if action == true_action:
            correct_predictions += 1
            weighted_correct_predictions += 2
        elif action > true_action:
            overestimations += 1
            weighted_overestimations += 1

    accuracy = correct_predictions / len(X_test)
    directional_accuracy = (correct_predictions + overestimations) / len(X_test)
    weighted_directional_accuracy = (weighted_correct_predictions + weighted_overestimations) / len(X_test)

    print("Precisão:", accuracy)
    print("Acurácia Direcional:", directional_accuracy)
    print("Acurácia Direcional Ponderada:", weighted_directional_accuracy)

    plt.figure(figsize=(12, 6))
    plt.plot(epoch_accuracies, label='Precisão')
    plt.plot(epoch_directional_accuracies, label='Acurácia Direcional')
    plt.plot(epoch_weighted_directional_accuracies, label='Acurácia Direcional Ponderada')
    plt.xlabel('Época')
    plt.ylabel('Métrica')
    plt.title('Desempenho do Modelo ao Longo das Épocas')
    plt.legend()
    plt.show()

    plt.figure(figsize=(10, 5))
    metrics = [accuracy, directional_accuracy, weighted_directional_accuracy]
    metric_labels = ['Precisão', 'Acurácia Direcional', 'Acurácia Direcional Ponderada']
    colors = ['blue', 'orange', 'green']
    plt.bar(metric_labels, metrics, color=colors)
    plt.xlabel('Métricas')
    plt.ylabel('Valor')
    plt.title('Métricas de Desempenho no Conjunto de Teste')
    plt.ylim(0, 1)
    plt.show()

    dqn_agent.model.save('AgenteAposta.h5')
    data_save = pd.DataFrame({'epoch_accuracies': epoch_accuracies,
                              'epoch_directional_accuracies': epoch_directional_accuracies,
                              'epoch_weighted_directional_accuracies': epoch_weighted_directional_accuracies})
    data_save.to_csv('/home/darkcover/Documentos/Out/dados/metricas_aposta.csv', index=False)

if __name__ == '__main__':
    main()
# Out:
# 2024-06-22 20:36:55.362690: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-06-22 20:36:55.456585: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-06-22 20:36:55.828506: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-06-22 20:36:58.095472: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Época 1/10 - Precisão: 1.9945, Acurácia Direcional: 3.9613, Acurácia Direcional Ponderada: 5.9557
# Época 2/10 - Precisão: 1.9969, Acurácia Direcional: 3.9622, Acurácia Direcional Ponderada: 5.9591
# Época 3/10 - Precisão: 1.9986, Acurácia Direcional: 3.9607, Acurácia Direcional Ponderada: 5.9592
# Época 4/10 - Precisão: 2.0137, Acurácia Direcional: 3.9602, Acurácia Direcional Ponderada: 5.9740
# Época 5/10 - Precisão: 2.0152, Acurácia Direcional: 3.9603, Acurácia Direcional Ponderada: 5.9755
# Época 6/10 - Precisão: 2.0267, Acurácia Direcional: 3.9603, Acurácia Direcional Ponderada: 5.9870
# Época 7/10 - Precisão: 2.0251, Acurácia Direcional: 3.9604, Acurácia Direcional Ponderada: 5.9855
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 202
#     199     data_save.to_csv('/home/darkcover/Documentos/Out/dados/metricas_aposta.csv', index=False)
#     201 if __name__ == '__main__':
# --> 202     main()
#
# Cell In[1], line 114, in main()
#     112 for i in range(len(X_train) - 1):
#     113     state = X_train[i, :]
# --> 114     action = dqn_agent.get_action(state)
#     115     true_action = y_train[i]
#     116     acerto = acerto_train[i][0]
#
# Cell In[1], line 40, in DQNAgent.get_action(self, state)
#      38     return np.random.choice(self.n_actions)
#      39 else:
# ---> 40     q_values = self.model.predict(state.reshape(1, -1), batch_size=1, verbose=0)
#      41     return np.argmax(q_values)
#
# File ~/Documentos/Out/venv/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/Documentos/Out/venv/lib/python3.10/site-packages/keras/src/backend/tensorflow/trainer.py:442, in TensorFlowTrainer.predict(self, x, batch_size, verbose, steps, callbacks)
#     437 @traceback_utils.filter_traceback
#     438 def predict(
#     439     self, x, batch_size=None, verbose="auto", steps=None, callbacks=None
#     440 ):
#     441     # Create an iterator that yields batches of input data.
# --> 442     epoch_iterator = TFEpochIterator(
#     443         x=x,
#     444         batch_size=batch_size,
#     445         steps_per_epoch=steps,
#     446         shuffle=False,
#     447         distribute_strategy=self.distribute_strategy,
#     448         steps_per_execution=self.steps_per_execution,
#     449     )
#     451     # Container that configures and calls callbacks.
#     452     if not isinstance(callbacks, callbacks_module.CallbackList):
#
# File ~/Documentos/Out/venv/lib/python3.10/site-packages/keras/src/backend/tensorflow/trainer.py:625, in TFEpochIterator.__init__(self, distribute_strategy, *args, **kwargs)
#     623 super().__init__(*args, **kwargs)
#     624 self._distribute_strategy = distribute_strategy
# --> 625 dataset = self._get_iterator()
#     626 if not isinstance(dataset, tf.distribute.DistributedDataset):
#     627     dataset = self._distribute_strategy.experimental_distribute_dataset(
#     628         dataset
#     629     )
#
# File ~/Documentos/Out/venv/lib/python3.10/site-packages/keras/src/backend/tensorflow/trainer.py:634, in TFEpochIterator._get_iterator(self)
#     633 def _get_iterator(self):
# --> 634     return self.data_adapter.get_tf_dataset()
#
# File ~/Documentos/Out/venv/lib/python3.10/site-packages/keras/src/trainers/data_adapters/array_data_adapter.py:236, in ArrayDataAdapter.get_tf_dataset(self)
#     233 if shuffle == "batch":
#     234     indices_dataset = indices_dataset.map(tf.random.shuffle)
# --> 236 dataset = slice_inputs(indices_dataset, self._inputs)
#     238 options = tf.data.Options()
#     239 options.experimental_distribute.auto_shard_policy = (
#     240     tf.data.experimental.AutoShardPolicy.DATA
#     241 )
#
# File ~/Documentos/Out/venv/lib/python3.10/site-packages/keras/src/trainers/data_adapters/array_data_adapter.py:215, in ArrayDataAdapter.get_tf_dataset.<locals>.slice_inputs(indices_dataset, inputs)
#     211         return x
#     213     return tree.traverse(grab_one, data)
# --> 215 dataset = dataset.map(
#     216     grab_batch, num_parallel_calls=tf.data.AUTOTUNE
#     217 )
#     219 # Default optimizations are disabled to avoid the overhead of
#     220 # (unnecessary) input pipeline graph serialization & deserialization
#     221 options = tf.data.Options()
#
# File ~/Documentos/Out/venv/lib/python3.10/site-packages/tensorflow/python/data/ops/dataset_ops.py:2299, in DatasetV2.map(self, map_func, num_parallel_calls, deterministic, name)
#    2295 # Loaded lazily due to a circular dependency (dataset_ops -> map_op ->
#    2296 # dataset_ops).
#    2297 # pylint: disable=g-import-not-at-top,protected-access
#    2298 from tensorflow.python.data.ops import map_op
# -> 2299 return map_op._map_v2(
#    2300     self,
#    2301     map_func,
#    2302     num_parallel_calls=num_parallel_calls,
#    2303     deterministic=deterministic,
#    2304     name=name)
#
# File ~/Documentos/Out/venv/lib/python3.10/site-packages/tensorflow/python/data/ops/map_op.py:40, in _map_v2(input_dataset, map_func, num_parallel_calls, deterministic, name)
#      37   return _MapDataset(
#      38       input_dataset, map_func, preserve_cardinality=True, name=name)
#      39 else:
# ---> 40   return _ParallelMapDataset(
#      41       input_dataset,
#      42       map_func,
#      43       num_parallel_calls=num_parallel_calls,
#      44       deterministic=deterministic,
#      45       preserve_cardinality=True,
#      46       name=name)
#
# File ~/Documentos/Out/venv/lib/python3.10/site-packages/tensorflow/python/data/ops/map_op.py:148, in _ParallelMapDataset.__init__(self, input_dataset, map_func, num_parallel_calls, deterministic, use_inter_op_parallelism, preserve_cardinality, use_legacy_function, name)
#     146 self._input_dataset = input_dataset
#     147 self._use_inter_op_parallelism = use_inter_op_parallelism
# --> 148 self._map_func = structured_function.StructuredFunctionWrapper(
#     149     map_func,
#     150     self._transformation_name(),
#     151     dataset=input_dataset,
#     152     use_legacy_function=use_legacy_function)
#     153 if deterministic is None:
#     154   self._deterministic = "default"
#
# File ~/Documentos/Out/venv/lib/python3.10/site-packages/tensorflow/python/data/ops/structured_function.py:265, in StructuredFunctionWrapper.__init__(self, func, transformation_name, dataset, input_classes, input_shapes, input_types, input_structure, add_to_graph, use_legacy_function, defun_kwargs)
#     258       warnings.warn(
#     259           "Even though the `tf.config.experimental_run_functions_eagerly` "
#     260           "option is set, this option does not apply to tf.data functions. "
#     261           "To force eager execution of tf.data functions, please use "
#     262           "`tf.data.experimental.enable_debug_mode()`.")
#     263     fn_factory = trace_tf_function(defun_kwargs)
# --> 265 self._function = fn_factory()
#     266 # There is no graph to add in eager mode.
#     267 add_to_graph &= not context.executing_eagerly()
#
# File ~/Documentos/Out/venv/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:1251, in Function.get_concrete_function(self, *args, **kwargs)
#    1249 def get_concrete_function(self, *args, **kwargs):
#    1250   # Implements PolymorphicFunction.get_concrete_function.
# -> 1251   concrete = self._get_concrete_function_garbage_collected(*args, **kwargs)
#    1252   concrete._garbage_collector.release()  # pylint: disable=protected-access
#    1253   return concrete
#
# File ~/Documentos/Out/venv/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:1221, in Function._get_concrete_function_garbage_collected(self, *args, **kwargs)
#    1219   if self._variable_creation_config is None:
#    1220     initializers = []
# -> 1221     self._initialize(args, kwargs, add_initializers_to=initializers)
#    1222     self._initialize_uninitialized_variables(initializers)
#    1224 if self._created_variables:
#    1225   # In this case we have created variables on the first call, so we run the
#    1226   # version which is guaranteed to never create variables.
#
# File ~/Documentos/Out/venv/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:696, in Function._initialize(self, args, kwds, add_initializers_to)
#     691 self._variable_creation_config = self._generate_scoped_tracing_options(
#     692     variable_capturing_scope,
#     693     tracing_compilation.ScopeType.VARIABLE_CREATION,
#     694 )
#     695 # Force the definition of the function for these arguments
# --> 696 self._concrete_variable_creation_fn = tracing_compilation.trace_function(
#     697     args, kwds, self._variable_creation_config
#     698 )
#     700 def invalid_creator_scope(*unused_args, **unused_kwds):
#     701   """Disables variable creation."""
#
# File ~/Documentos/Out/venv/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:178, in trace_function(args, kwargs, tracing_options)
#     175     args = tracing_options.input_signature
#     176     kwargs = {}
# --> 178   concrete_function = _maybe_define_function(
#     179       args, kwargs, tracing_options
#     180   )
#     182 if not tracing_options.bind_graph_to_function:
#     183   concrete_function._garbage_collector.release()  # pylint: disable=protected-access
#
# File ~/Documentos/Out/venv/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:283, in _maybe_define_function(args, kwargs, tracing_options)
#     281 else:
#     282   target_func_type = lookup_func_type
# --> 283 concrete_function = _create_concrete_function(
#     284     target_func_type, lookup_func_context, func_graph, tracing_options
#     285 )
#     287 if tracing_options.function_cache is not None:
#     288   tracing_options.function_cache.add(
#     289       concrete_function, current_func_context
#     290   )
#
# File ~/Documentos/Out/venv/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:303, in _create_concrete_function(function_type, type_context, func_graph, tracing_options)
#     299 placeholder_context = trace_type.InternalPlaceholderContext(
#     300     func_graph, type_context.get_placeholder_mapping()
#     301 )
#     302 with func_graph.as_default():
# --> 303   placeholder_bound_args = function_type.placeholder_arguments(
#     304       placeholder_context
#     305   )
#     307 disable_acd = tracing_options.attributes and tracing_options.attributes.get(
#     308     attributes_lib.DISABLE_ACD, False
#     309 )
#     310 traced_func_graph = func_graph_module.func_graph_from_py_func(
#     311     tracing_options.name,
#     312     tracing_options.python_function,
#    (...)
#     319     create_placeholders=False,
#     320 )
#
# File ~/Documentos/Out/venv/lib/python3.10/site-packages/tensorflow/core/function/polymorphism/function_type.py:356, in FunctionType.placeholder_arguments(self, placeholder_context)
#     353     raise ValueError("Can not generate placeholder value for "
#     354                      "partially defined function type.")
#     355   placeholder_context.update_naming_scope(parameter.name)
# --> 356   arguments[parameter.name] = parameter.type_constraint.placeholder_value(
#     357       placeholder_context)
#     359 return inspect.BoundArguments(self, arguments)
#
# File ~/Documentos/Out/venv/lib/python3.10/site-packages/tensorflow/python/framework/tensor.py:1021, in TensorSpec.placeholder_value(self, placeholder_context)
#    1019     placeholder = self._graph_placeholder(context_graph, name=name)
#    1020 else:
# -> 1021   placeholder = self._graph_placeholder(context_graph, name=name)
#    1023 if name is not None:
#    1024   # Record the requested/user-specified name in case it's different than
#    1025   # the uniquified name, for validation when exporting signatures.
#    1026   placeholder.op._set_attr(  # pylint: disable=protected-access
#    1027       "_user_specified_name",
#    1028       attr_value_pb2.AttrValue(s=compat.as_bytes(name)))
#
# File ~/Documentos/Out/venv/lib/python3.10/site-packages/tensorflow/python/framework/tensor.py:1070, in TensorSpec._graph_placeholder(self, graph, name)
#    1067   op = graph._create_op_internal(  # pylint: disable=protected-access
#    1068       "Placeholder", [], [dtype], input_types=[], attrs=attrs)
#    1069 (result,) = op.outputs
# -> 1070 if op_callbacks.should_invoke_op_callbacks():
#    1071   # TODO(b/147670703): Once the special-op creation code paths
#    1072   # are unified. Remove this `if` block.
#    1073   callback_outputs = op_callbacks.invoke_op_callbacks(
#    1074       "Placeholder", tuple(), attrs, tuple(op.outputs),
#    1075       op_name=name, graph=graph)
#    1076   if callback_outputs is not None:
#
# File ~/Documentos/Out/venv/lib/python3.10/site-packages/tensorflow/python/framework/op_callbacks.py:122, in should_invoke_op_callbacks()
#     115 """Determine if op callbacks are present and should be invoked.
#     116
#     117 Returns:
#     118   A thread-local result (boolean) indicating whether any op callback(s) exist
#     119   and should be invoked.
#     120 """
#     121 ctx = context.context()
# --> 122 return ctx.op_callbacks and not ctx.invoking_op_callbacks
#
# File ~/Documentos/Out/venv/lib/python3.10/site-packages/tensorflow/python/eager/context.py:1553, in Context.op_callbacks(self)
#    1548     raise KeyError("The specified op callback has not been registered, "
#    1549                    "and hence cannot be removed.")
#    1550   del self._thread_local_data.op_callbacks[
#    1551       self._thread_local_data.op_callbacks.index(callback)]
# -> 1553 @property
#    1554 def op_callbacks(self):
#    1555   return self._thread_local_data.op_callbacks
#    1557 @property
#    1558 def invoking_op_callbacks(self):
#
# KeyboardInterrupt:

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import tensorflow as tf
from collections import deque
import random
import matplotlib.pyplot as plt

class DQNAgent:
    def __init__(self, n_states, n_actions, learning_rate, gamma, epsilon, epsilon_decay, epsilon_min, buffer_size=10000):
        self.n_states = n_states
        self.n_actions = n_actions
        self.learning_rate = learning_rate
        self.gamma = gamma
        self.epsilon = epsilon
        self.epsilon_decay = epsilon_decay
        self.epsilon_min = epsilon_min
        self.memory = deque(maxlen=buffer_size)
        self.model = self.build_model()
        self.model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate), loss=tf.keras.losses.Huber())

    def build_model(self):
        model = tf.keras.Sequential([
            tf.keras.layers.Input(shape=(self.n_states,)),
            tf.keras.layers.Dense(256, activation='relu'),
            tf.keras.layers.BatchNormalization(),
            tf.keras.layers.Dropout(0.2),
            tf.keras.layers.Dense(256, activation='relu'),
            tf.keras.layers.BatchNormalization(),
            tf.keras.layers.Dropout(0.2),
            tf.keras.layers.Dense(self.n_actions, activation='linear')
        ])
        return model

    def get_action(self, state):
        if np.random.random() < self.epsilon:
            return np.random.choice(self.n_actions)
        else:
            q_values = self.model.predict(state.reshape(1, -1), batch_size=1, verbose=0)
            return np.argmax(q_values)

    def remember(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))

    def replay(self, batch_size):
        if len(self.memory) < batch_size:
            return
        minibatch = random.sample(self.memory, batch_size)
        for state, action, reward, next_state, done in minibatch:
            target = reward
            if not done:
                target = reward + self.gamma * np.amax(self.model.predict(next_state.reshape(1, -1), batch_size=1, verbose=0))
            target_f = self.model.predict(state.reshape(1, -1), batch_size=1, verbose=0)
            target_f[0][action] = target
            self.model.fit(state.reshape(1, -1), target_f, epochs=1, verbose=0)

    def update_epsilon(self):
        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay

def calculate_reward(action, acerto):
    reward = 0
    if action == 1:  # Apostou
        if acerto == 1:
            reward = 1  # Recompensa por apostar corretamente
        elif acerto == 0:
            reward = -1  # Penalidade por apostar incorretamente
    return reward

def normalize_data(features):
    scaler = StandardScaler()
    return scaler.fit_transform(features)

def main():
    # Carregar os dados
    data = pd.read_csv('/home/darkcover/Documentos/Out/dados/data_final2.csv')

    # Selecionar as features e a variável de saída
    features = data[['odd_entrada', 'media5', 'media10', 'media20', 'media40', 'media80', 'media160', 'media320', 'media640']].values
    actions = data['apostar'].values  # Variável de saída: se deve apostar ou não
    acertos = data[['acerto', 'level', 'contagem']].values  # Variável de saída para calcular a recompensa

    features = normalize_data(features)

    # Adicionar level e contagem às features
    features = np.hstack((features, acertos[:, 1:]))

    # Dividir os dados em treino e teste
    X_train, X_test, y_train, y_test, acerto_train, acerto_test = train_test_split(features, actions, acertos, test_size=0.2, random_state=42)

    # Parâmetros de treinamento
    n_epochs = 25
    batch_size = 256

    # Crie o agente DQN
    n_states = X_train.shape[1]
    n_actions = 2  # Ações possíveis: apostar ou não apostar
    dqn_agent = DQNAgent(n_states, n_actions, learning_rate=0.001, gamma=0.99, epsilon=1.0, epsilon_decay=0.99, epsilon_min=0.01, buffer_size=10000)

    epoch_accuracies = []
    epoch_directional_accuracies = []
    epoch_weighted_directional_accuracies = []

    # Treinamento do agente
    for epoch in range(n_epochs):
        correct_predictions = 0
        overestimations = 0
        weighted_correct_predictions = 0
        weighted_overestimations = 0

        for i in range(len(X_train) - 1):
            state = X_train[i, :]
            action = dqn_agent.get_action(state)
            true_action = y_train[i]
            acerto = acerto_train[i][0]
            reward = calculate_reward(action, acerto)
            next_state = X_train[i + 1, :]
            done = (i == len(X_train) - 2)

            dqn_agent.remember(state, action, reward, next_state, done)

            if done:
                dqn_agent.replay(batch_size)
                dqn_agent.update_epsilon()

            if action == true_action:
                correct_predictions += 1
                weighted_correct_predictions += 2  # Peso maior para acertos exatos
            elif action > true_action:
                overestimations += 1
                weighted_overestimations += 1  # Peso menor para erros

        epoch_accuracy = correct_predictions / len(X_test)
        epoch_directional_accuracy = (correct_predictions + overestimations) / len(X_test)
        epoch_weighted_directional_accuracy = (weighted_correct_predictions + weighted_overestimations) / len(X_test)

        epoch_accuracies.append(epoch_accuracy)
        epoch_directional_accuracies.append(epoch_directional_accuracy)
        epoch_weighted_directional_accuracies.append(epoch_weighted_directional_accuracy)

        print(f'Época {epoch + 1}/{n_epochs} - Precisão: {epoch_accuracy:.4f}, Acurácia Direcional: {epoch_directional_accuracy:.4f}, Acurácia Direcional Ponderada: {epoch_weighted_directional_accuracy:.4f}')

    # Teste o agente
    correct_predictions = 0
    overestimations = 0
    weighted_correct_predictions = 0
    weighted_overestimations = 0

    predicted_actions = []

    for i in range(len(X_test)):
        state = X_test[i, :]
        action = dqn_agent.get_action(state)
        true_action = y_test[i]

        predicted_actions.append(action)

        if action == true_action:
            correct_predictions += 1
            weighted_correct_predictions += 2
        elif action > true_action:
            overestimations += 1
            weighted_overestimations += 1

    accuracy = correct_predictions / len(X_test)
    directional_accuracy = (correct_predictions + overestimations) / len(X_test)
    weighted_directional_accuracy = (weighted_correct_predictions + weighted_overestimations) / len(X_test)

    print("Precisão:", accuracy)
    print("Acurácia Direcional:", directional_accuracy)
    print("Acurácia Direcional Ponderada:", weighted_directional_accuracy)

    plt.figure(figsize=(12, 6))
    plt.plot(epoch_accuracies, label='Precisão')
    plt.plot(epoch_directional_accuracies, label='Acurácia Direcional')
    plt.plot(epoch_weighted_directional_accuracies, label='Acurácia Direcional Ponderada')
    plt.xlabel('Época')
    plt.ylabel('Métrica')
    plt.title('Desempenho do Modelo ao Longo das Épocas')
    plt.legend()
    plt.show()

    plt.figure(figsize=(10, 5))
    metrics = [accuracy, directional_accuracy, weighted_directional_accuracy]
    metric_labels = ['Precisão', 'Acurácia Direcional', 'Acurácia Direcional Ponderada']
    colors = ['blue', 'orange', 'green']
    plt.bar(metric_labels, metrics, color=colors)
    plt.xlabel('Métricas')
    plt.ylabel('Valor')
    plt.title('Métricas de Desempenho no Conjunto de Teste')
    plt.ylim(0, 1)
    plt.show()

    dqn_agent.model.save('AgenteAposta.h5')
    data_save = pd.DataFrame({'epoch_accuracies': epoch_accuracies,
                              'epoch_directional_accuracies': epoch_directional_accuracies,
                              'epoch_weighted_directional_accuracies': epoch_weighted_directional_accuracies})
    data_save.to_csv('/home/darkcover/Documentos/Out/dados/metricas_aposta.csv', index=False)

if __name__ == '__main__':
    main()
# Out:
# Época 1/25 - Precisão: 2.0044, Acurácia Direcional: 3.9607, Acurácia Direcional Ponderada: 5.9651
# Época 2/25 - Precisão: 2.0059, Acurácia Direcional: 3.9604, Acurácia Direcional Ponderada: 5.9663
# Época 3/25 - Precisão: 2.0122, Acurácia Direcional: 3.9608, Acurácia Direcional Ponderada: 5.9729
# Época 4/25 - Precisão: 2.0118, Acurácia Direcional: 3.9614, Acurácia Direcional Ponderada: 5.9731
# Época 5/25 - Precisão: 2.0047, Acurácia Direcional: 3.9617, Acurácia Direcional Ponderada: 5.9665
# Época 6/25 - Precisão: 2.0196, Acurácia Direcional: 3.9612, Acurácia Direcional Ponderada: 5.9808
# Época 7/25 - Precisão: 2.0172, Acurácia Direcional: 3.9613, Acurácia Direcional Ponderada: 5.9785
# Época 8/25 - Precisão: 2.0414, Acurácia Direcional: 3.9612, Acurácia Direcional Ponderada: 6.0026
# Época 9/25 - Precisão: 2.0386, Acurácia Direcional: 3.9599, Acurácia Direcional Ponderada: 5.9985
# Época 10/25 - Precisão: 2.0307, Acurácia Direcional: 3.9598, Acurácia Direcional Ponderada: 5.9905
# Época 11/25 - Precisão: 2.0324, Acurácia Direcional: 3.9594, Acurácia Direcional Ponderada: 5.9919
# Época 12/25 - Precisão: 2.0497, Acurácia Direcional: 3.9589, Acurácia Direcional Ponderada: 6.0086
# Época 13/25 - Precisão: 2.0458, Acurácia Direcional: 3.9588, Acurácia Direcional Ponderada: 6.0046
# Época 14/25 - Precisão: 2.0402, Acurácia Direcional: 3.9583, Acurácia Direcional Ponderada: 5.9985
# Época 15/25 - Precisão: 2.0754, Acurácia Direcional: 3.9585, Acurácia Direcional Ponderada: 6.0339
# Época 16/25 - Precisão: 2.0526, Acurácia Direcional: 3.9583, Acurácia Direcional Ponderada: 6.0109
# Época 17/25 - Precisão: 2.0544, Acurácia Direcional: 3.9599, Acurácia Direcional Ponderada: 6.0143
# Época 18/25 - Precisão: 2.0917, Acurácia Direcional: 3.9583, Acurácia Direcional Ponderada: 6.0499
# Época 19/25 - Precisão: 2.0823, Acurácia Direcional: 3.9575, Acurácia Direcional Ponderada: 6.0398
# Época 20/25 - Precisão: 2.1214, Acurácia Direcional: 3.9569, Acurácia Direcional Ponderada: 6.0782
# Época 21/25 - Precisão: 2.1320, Acurácia Direcional: 3.9552, Acurácia Direcional Ponderada: 6.0872
# Época 22/25 - Precisão: 2.1126, Acurácia Direcional: 3.9566, Acurácia Direcional Ponderada: 6.0693
# Época 23/25 - Precisão: 2.1228, Acurácia Direcional: 3.9565, Acurácia Direcional Ponderada: 6.0793
# Época 24/25 - Precisão: 2.1153, Acurácia Direcional: 3.9558, Acurácia Direcional Ponderada: 6.0710
# Época 25/25 - Precisão: 2.1144, Acurácia Direcional: 3.9562, Acurácia Direcional Ponderada: 6.0706
# Precisão: 0.52975
# Acurácia Direcional: 0.988125
# Acurácia Direcional Ponderada: 1.517875
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
import matplotlib.pyplot as plt

def load_and_preprocess_data(file_path):
    # Carregar os dados
    data = pd.read_csv(file_path)

    # Selecionar as features e a variável de saída
    features = data[['odd_entrada', 'media5', 'media10', 'media20', 'media40', 'media80', 'media160', 'media320', 'media640']].values
    actions = data['apostar'].values  # Variável de saída: se deve apostar ou não
    acertos = data[['acerto', 'level', 'contagem']].values  # Variável de saída para calcular a recompensa

    # Normalizar os dados
    scaler = StandardScaler()
    features = scaler.fit_transform(features)

    # Adicionar level e contagem às features
    features = np.hstack((features, acertos[:, 1:]))

    return features, actions, acertos

def build_model(input_shape, n_actions):
    # Defina a arquitetura do modelo conforme o modelo fornecido
    model = tf.keras.Sequential([
        tf.keras.layers.Input(shape=(input_shape,)),
        tf.keras.layers.Dense(256, activation='relu'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dropout(0.2),
        tf.keras.layers.Dense(256, activation='relu'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dropout(0.2),
        tf.keras.layers.Dense(n_actions, activation='linear')
    ])
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), loss=tf.keras.losses.Huber())
    return model

def test_model(model_path, test_data_path):
    # Carregar e preprocessar os dados de teste
    X_test, y_test, acerto_test = load_and_preprocess_data(test_data_path)

    # Construir o modelo com a mesma arquitetura e carregar os pesos
    n_states = X_test.shape[1]
    n_actions = 2  # Ações possíveis: apostar ou não apostar
    model = build_model(n_states, n_actions)
    model.load_weights(model_path)

    correct_predictions = 0
    overestimations = 0
    weighted_correct_predictions = 0
    weighted_overestimations = 0

    predicted_actions = []

    for i in range(len(X_test)):
        state = X_test[i, :]
        q_values = model.predict(state.reshape(1, -1), batch_size=1, verbose=0)
        action = np.argmax(q_values)
        true_action = y_test[i]

        predicted_actions.append(action)

        if action == true_action:
            correct_predictions += 1
            weighted_correct_predictions += 2
        elif action > true_action:
            overestimations += 1
            weighted_overestimations += 1

    accuracy = correct_predictions / len(X_test)
    directional_accuracy = (correct_predictions + overestimations) / len(X_test)
    weighted_directional_accuracy = (weighted_correct_predictions + weighted_overestimations) / len(X_test)

    print("Precisão:", accuracy)
    print("Acurácia Direcional:", directional_accuracy)
    print("Acurácia Direcional Ponderada:", weighted_directional_accuracy)

    plt.figure(figsize=(10, 5))
    metrics = [accuracy, directional_accuracy, weighted_directional_accuracy]
    metric_labels = ['Precisão', 'Acurácia Direcional', 'Acurácia Direcional Ponderada']
    colors = ['blue', 'orange', 'green']
    plt.bar(metric_labels, metrics, color=colors)
    plt.xlabel('Métricas')
    plt.ylabel('Valor')
    plt.title('Métricas de Desempenho no Conjunto de Teste')
    plt.ylim(0, 1)
    plt.show()

# Caminho para o modelo salvo e a nova planilha de dados
model_path = '/home/darkcover/Documentos/Out/Colab_Notebooks/Order/AgenteAposta.keras'
test_data_path = '/home/darkcover/Documentos/Out/dados/data_final2.csv'

test_model(model_path, test_data_path)
# Out:
# /home/darkcover/Documentos/Out/venv/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:415: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 22 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import tensorflow as tf
from collections import deque
import random
import matplotlib.pyplot as plt

class DQNAgent:
    def __init__(self, n_states, n_actions, learning_rate, gamma, epsilon, epsilon_decay, epsilon_min, buffer_size=10000):
        self.n_states = n_states
        self.n_actions = n_actions
        self.learning_rate = learning_rate
        self.gamma = gamma
        self.epsilon = epsilon
        self.epsilon_decay = epsilon_decay
        self.epsilon_min = epsilon_min
        self.memory = deque(maxlen=buffer_size)
        self.model = self.build_model()
        self.model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate), loss=tf.keras.losses.Huber())

    def build_model(self):
        model = tf.keras.Sequential([
            tf.keras.layers.Input(shape=(self.n_states,)),
            tf.keras.layers.Dense(256, activation='relu'),
            tf.keras.layers.BatchNormalization(),
            tf.keras.layers.Dropout(0.2),
            tf.keras.layers.Dense(256, activation='relu'),
            tf.keras.layers.BatchNormalization(),
            tf.keras.layers.Dropout(0.2),
            tf.keras.layers.Dense(self.n_actions, activation='linear')
        ])
        return model

    def get_action(self, state):
        if np.random.random() < self.epsilon:
            return np.random.choice(self.n_actions)
        else:
            q_values = self.model.predict(state.reshape(1, -1), batch_size=1, verbose=0)
            return np.argmax(q_values)

    def remember(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))

    def replay(self, batch_size):
        if len(self.memory) < batch_size:
            return
        minibatch = random.sample(self.memory, batch_size)
        for state, action, reward, next_state, done in minibatch:
            target = reward
            if not done:
                target = reward + self.gamma * np.amax(self.model.predict(next_state.reshape(1, -1), batch_size=1, verbose=0))
            target_f = self.model.predict(state.reshape(1, -1), batch_size=1, verbose=0)
            target_f[0][action] = target
            self.model.fit(state.reshape(1, -1), target_f, epochs=1, verbose=0)

    def update_epsilon(self):
        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay

def calculate_reward(action, acerto):
    reward = 0
    if action == 1:  # Apostou
        if acerto == 1:
            reward = 2  # Recompensa por apostar corretamente
        elif acerto == 0:
            reward = -1  # Penalidade por apostar incorretamente
    return reward

def normalize_data(features):
    scaler = StandardScaler()
    return scaler.fit_transform(features)

def main():
    # Carregar os dados
    data = pd.read_csv('/home/darkcover/Documentos/Out/dados/data_final2.csv')

    # Selecionar as features e a variável de saída
    features = data[['odd_entrada', 'media5', 'media10', 'media20', 'media40', 'media80', 'media160', 'media320', 'media640']].values
    actions = data['apostar'].values  # Variável de saída: se deve apostar ou não
    acertos = data[['acerto', 'level', 'contagem']].values  # Variável de saída para calcular a recompensa

    features = normalize_data(features)

    # Adicionar level e contagem às features
    features = np.hstack((features, acertos[:, 1:]))

    # Dividir os dados em treino e teste
    X_train, X_test, y_train, y_test, acerto_train, acerto_test = train_test_split(features, actions, acertos, test_size=0.2, random_state=42)

    # Parâmetros de treinamento
    n_epochs = 25  # Aumentar o número de épocas
    batch_size = 128  # Tentar um tamanho de lote menor para mais atualizações

    # Crie o agente DQN
    n_states = X_train.shape[1]
    n_actions = 2  # Ações possíveis: apostar ou não apostar
    dqn_agent = DQNAgent(n_states, n_actions, learning_rate=0.001, gamma=0.99, epsilon=1.0, epsilon_decay=0.99, epsilon_min=0.01, buffer_size=10000)

    epoch_accuracies = []
    epoch_directional_accuracies = []
    epoch_weighted_directional_accuracies = []

    # Treinamento do agente
    for epoch in range(n_epochs):
        correct_predictions = 0
        overestimations = 0
        weighted_correct_predictions = 0
        weighted_overestimations = 0

        for i in range(len(X_train) - 1):
            state = X_train[i, :]
            action = dqn_agent.get_action(state)
            true_action = y_train[i]
            acerto = acerto_train[i][0]
            reward = calculate_reward(action, acerto)
            next_state = X_train[i + 1, :]
            done = (i == len(X_train) - 2)

            dqn_agent.remember(state, action, reward, next_state, done)

            if done:
                dqn_agent.replay(batch_size)
                dqn_agent.update_epsilon()

            if action == true_action:
                correct_predictions += 1
                weighted_correct_predictions += 2  # Peso maior para acertos exatos
            elif action > true_action:
                overestimations += 1
                weighted_overestimations += 1  # Peso menor para erros

        epoch_accuracy = correct_predictions / len(X_train)
        epoch_directional_accuracy = (correct_predictions + overestimations) / len(X_train)
        epoch_weighted_directional_accuracy = (weighted_correct_predictions + weighted_overestimations) / len(X_train)

        epoch_accuracies.append(epoch_accuracy)
        epoch_directional_accuracies.append(epoch_directional_accuracy)
        epoch_weighted_directional_accuracies.append(epoch_weighted_directional_accuracy)

        print(f'Época {epoch + 1}/{n_epochs} - Precisão: {epoch_accuracy:.4f}, Acurácia Direcional: {epoch_directional_accuracy:.4f}, Acurácia Direcional Ponderada: {epoch_weighted_directional_accuracy:.4f}')

    # Teste o agente
    correct_predictions = 0
    overestimations = 0
    weighted_correct_predictions = 0
    weighted_overestimations = 0

    predicted_actions = []

    for i in range(len(X_test)):
        state = X_test[i, :]
        action = dqn_agent.get_action(state)
        true_action = y_test[i]

        predicted_actions.append(action)

        if action == true_action:
            correct_predictions += 1
            weighted_correct_predictions += 2
        elif action > true_action:
            overestimations += 1
            weighted_overestimations += 1

    accuracy = correct_predictions / len(X_test)
    directional_accuracy = (correct_predictions + overestimations) / len(X_test)
    weighted_directional_accuracy = (weighted_correct_predictions + weighted_overestimations) / len(X_test)

    print("Precisão:", accuracy)
    print("Acurácia Direcional:", directional_accuracy)
    print("Acurácia Direcional Ponderada:", weighted_directional_accuracy)

    # Matriz de Confusão
    conf_matrix = confusion_matrix(y_test, predicted_actions)
    print("Matriz de Confusão:\n", conf_matrix)

    disp = ConfusionMatrixDisplay(confusion_matrix=conf_matrix, display_labels=['Não Apostar', 'Apostar'])
    disp.plot(cmap=plt.cm.Blues)
    plt.show()

    plt.figure(figsize=(12, 6))
    plt.plot(epoch_accuracies, label='Precisão')
    plt.plot(epoch_directional_accuracies, label='Acurácia Direcional')
    plt.plot(epoch_weighted_directional_accuracies, label='Acurácia Direcional Ponderada')
    plt.xlabel('Época')
    plt.ylabel('Métrica')
    plt.title('Desempenho do Modelo ao Longo das Épocas')
    plt.legend()
    plt.show()

    plt.figure(figsize=(10, 5))
    metrics = [accuracy, directional_accuracy, weighted_directional_accuracy]
    metric_labels = ['Precisão', 'Acurácia Direcional', 'Acurácia Direcional Ponderada']
    colors = ['blue', 'orange', 'green']
    plt.bar(metric_labels, metrics, color=colors)
    plt.xlabel('Métricas')
    plt.ylabel('Valor')
    plt.title('Métricas de Desempenho no Conjunto de Teste')
    plt.ylim(0, 1)
    plt.show()

    dqn_agent.model.save('AgenteAposta.keras')
    data_save = pd.DataFrame({'epoch_accuracies': epoch_accuracies,
                              'epoch_directional_accuracies': epoch_directional_accuracies,
                              'epoch_weighted_directional_accuracies': epoch_weighted_directional_accuracies})
    data_save.to_csv('/home/darkcover/Documentos/Out/dados/metricas_aposta.csv', index=False)
    
if __name__ == '__main__':
    main()

# %%
import pandas as pd
import numpy as np
import re
import datetime as dt
from datetime import timedelta, datetime, time
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.regularizers import l2
import tensorflow as tf
import seaborn as sns
import matplotlib.pyplot as plt
from tensorflow import keras
from scipy.stats import entropy
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score, f1_score

import warnings
warnings.filterwarnings("ignore")
# Out:
# 2024-06-18 12:25:59.631988: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-06-18 12:25:59.737802: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-06-18 12:26:00.305591: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-06-18 12:26:04.285181: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Carregar os dados
data = pd.read_csv('/home/darkcover/Documentos/Out/dados/data_final.csv')

    # Selecionar as features e a variável de saída
features = data[['odd_entrada', 'media5', 'media10', 'media20', 'media40', 'media80', 'media160', 'media320', 'media640']].values
actions = data['apostar'].values  # Variável de saída: se deve apostar ou não

# %%
# Separar recursos (X) e rótulos (y)
X1 = features
y1 = actions

# Normalizar os recursos (importante para redes neurais)
scaler1 = StandardScaler()
X1 = scaler1.fit_transform(X1)

# Divida seus dados em conjuntos de treinamento e teste
X_train, X_test, y_train, y_test = train_test_split(X1, y1, test_size=0.2, random_state=42)

# Crie uma instância do GradientBoostingClassifier
clf = GradientBoostingClassifier()

# Execute a pesquisa de grade no conjunto de treinamento
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

# Avalie o desempenho do modelo
accuracy = accuracy_score(y_test, y_pred)
print(f'Acurácia do modelo: {accuracy}')

# Calcular o F1-Score
f1 = f1_score(y_test, y_pred, average='weighted')
print(f'F1-Score do modelo: {f1}')
# Out:
# Acurácia do modelo: 1.0
# F1-Score do modelo: 1.0

# %%
import tensorflow as tf
from tensorflow import keras
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# Separar recursos (X) e rótulos (y)
X1 = features
y1 = actions

# Normalizar os recursos (importante para redes neurais)
scaler1 = StandardScaler()
X1 = scaler1.fit_transform(X1)


# Divida seus dados em conjuntos de treinamento e teste
X_train, X_test, y_train, y_test = train_test_split(X1, y1, test_size=0.2, random_state=42)

model = keras.Sequential([
    keras.layers.Dense(128, activation='relu', input_shape=(X_train.shape[1],)),
    keras.layers.Dropout(0.2),
    keras.layers.Dense(64, activation='relu'),
    keras.layers.Dropout(0.2),
    keras.layers.Dense(32, activation='relu'),
    keras.layers.Dense(12, activation='softmax')
])

early_stopping = keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True)

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.fit(X_train, y_train, epochs=250, batch_size=64, validation_split=0.1, callbacks=[early_stopping])

test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f'Acurácia nos dados de teste: {test_accuracy}')


# Fazer previsões
predictions = model.predict(X_test)

# Arredondar as previsões para obter rótulos de classe
predicted_labels = np.argmax(predictions, axis=1)

# Calcular o F1-Score
f1 = f1_score(y_test, predicted_labels, average='weighted')

print(f'F1-Score do modelo: {f1}')
# Out:
# Epoch 1/250
# 2250/2250 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - accuracy: 0.9648 - loss: 0.1858 - val_accuracy: 0.9911 - val_loss: 0.0270
# Epoch 2/250
# 2250/2250 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - accuracy: 0.9879 - loss: 0.0323 - val_accuracy: 0.9912 - val_loss: 0.0228
# Epoch 3/250
# 2250/2250 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.9912 - loss: 0.0227 - val_accuracy: 0.9899 - val_loss: 0.0260
# Epoch 4/250
# 2250/2250 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.9918 - loss: 0.0221 - val_accuracy: 0.9927 - val_loss: 0.0220
# Epoch 5/250
# 2250/2250 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.9931 - loss: 0.0195 - val_accuracy: 0.9946 - val_loss: 0.0171
# Epoch 6/250
# 2250/2250 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.9937 - loss: 0.0164 - val_accuracy: 0.9934 - val_loss: 0.0227
# Epoch 7/250
# 2250/2250 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.9933 - loss: 0.0166 - val_accuracy: 0.9957 - val_loss: 0.0198
# Epoch 8/250
# 2250/2250 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.9935 - loss: 0.0165 - val_accuracy: 0.9952 - val_loss: 0.0268
# Epoch 9/250
# 2250/2250 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.9936 - loss: 0.0158 - val_accuracy: 0.9962 - val_loss: 0.0208
# Epoch 10/250
# 2250/2250 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.9945 - loss: 0.0144 - val_accuracy: 0.9951 - val_loss: 0.0261
# Epoch 11/250
# 2250/2250 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.9944 - loss: 0.0139 - val_accuracy: 0.9959 - val_loss: 0.0190
# Epoch 12/250
# 2250/2250 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.9942 - loss: 0.0141 - val_accuracy: 0.9958 - val_loss: 0.0267
# Epoch 13/250
# 2250/2250 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.9949 - loss: 0.0122 - val_accuracy: 0.9971 - val_loss: 0.0313
# Epoch 14/250
# 2250/2250 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.9951 - loss: 0.0120 - val_accuracy: 0.9951 - val_loss: 0.0289
# Epoch 15/250
# 2250/2250 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.9954 - loss: 0.0122 - val_accuracy: 0.9959 - val_loss: 0.0326
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9951 - loss: 0.0145
# Acurácia nos dados de teste: 0.9949749708175659
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# F1-Score do modelo: 0.9950266525968962

# %%
import tensorflow as tf
from tensorflow import keras
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import f1_score
import numpy as np

# Separar recursos (X) e rótulos (y)
X1 = features
y1 = actions

# Normalizar os recursos (importante para redes neurais)
scaler1 = StandardScaler()
X1 = scaler1.fit_transform(X1)

# Divida seus dados em conjuntos de treinamento e teste
X_train, X_test, y_train, y_test = train_test_split(X1, y1, test_size=0.2, random_state=42)

model = keras.Sequential([
    keras.layers.Dense(256, activation='relu', input_shape=(X_train.shape[1],)),
    keras.layers.Dropout(0.2),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dropout(0.2),
    keras.layers.Dense(64, activation='relu'),
    keras.layers.Dense(24, activation='softmax')
])

early_stopping = keras.callbacks.EarlyStopping(patience=50, restore_best_weights=True)

# Experimente diferentes funções de ativação, taxa de aprendizado e otimizador
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Aumente o número de épocas
model.fit(X_train, y_train, epochs=250, batch_size=64, validation_split=0.1, callbacks=[early_stopping])

test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f'Acurácia nos dados de teste: {test_accuracy}')

# Fazer previsões
predictions = model.predict(X_test)

# Arredondar as previsões para obter rótulos de classe
predicted_labels = np.argmax(predictions, axis=1)

# Calcular o F1-Score
f1 = f1_score(y_test, predicted_labels, average='weighted')

print(f'F1-Score do modelo: {f1}')
# Out:
# Epoch 1/250
# 2250/2250 ━━━━━━━━━━━━━━━━━━━━ 15s 5ms/step - accuracy: 0.9769 - loss: 0.1501 - val_accuracy: 0.9918 - val_loss: 0.0220
# Epoch 2/250
# 2250/2250 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - accuracy: 0.9898 - loss: 0.0261 - val_accuracy: 0.9917 - val_loss: 0.0221
# Epoch 3/250
# 2250/2250 ━━━━━━━━━━━━━━━━━━━━ 12s 5ms/step - accuracy: 0.9920 - loss: 0.0212 - val_accuracy: 0.9929 - val_loss: 0.0209
# Epoch 4/250
# 2250/2250 ━━━━━━━━━━━━━━━━━━━━ 21s 6ms/step - accuracy: 0.9927 - loss: 0.0188 - val_accuracy: 0.9945 - val_loss: 0.0194
# Epoch 5/250
# 2250/2250 ━━━━━━━━━━━━━━━━━━━━ 19s 5ms/step - accuracy: 0.9938 - loss: 0.0158 - val_accuracy: 0.9944 - val_loss: 0.0215
# Epoch 6/250
# 2250/2250 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9936 - loss: 0.0162 - val_accuracy: 0.9921 - val_loss: 0.0345
# Epoch 7/250
# 2250/2250 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - accuracy: 0.9937 - loss: 0.0150 - val_accuracy: 0.9949 - val_loss: 0.0276
# Epoch 8/250
# 2250/2250 ━━━━━━━━━━━━━━━━━━━━ 14s 6ms/step - accuracy: 0.9946 - loss: 0.0140 - val_accuracy: 0.9927 - val_loss: 0.0295
# Epoch 9/250
# 2250/2250 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - accuracy: 0.9947 - loss: 0.0131 - val_accuracy: 0.9964 - val_loss: 0.0202
# Epoch 10/250
# 2250/2250 ━━━━━━━━━━━━━━━━━━━━ 15s 7ms/step - accuracy: 0.9940 - loss: 0.0140 - val_accuracy: 0.9931 - val_loss: 0.0498
# Epoch 11/250
# 2250/2250 ━━━━━━━━━━━━━━━━━━━━ 14s 6ms/step - accuracy: 0.9949 - loss: 0.0128 - val_accuracy: 0.9959 - val_loss: 0.0428
# Epoch 12/250
# 2250/2250 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - accuracy: 0.9948 - loss: 0.0125 - val_accuracy: 0.9958 - val_loss: 0.0346
# Epoch 13/250
# 2250/2250 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - accuracy: 0.9949 - loss: 0.0122 - val_accuracy: 0.9956 - val_loss: 0.0528
# Epoch 14/250
# 2250/2250 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - accuracy: 0.9949 - loss: 0.0127 - val_accuracy: 0.9969 - val_loss: 0.0294
# Epoch 15/250
# 2250/2250 ━━━━━━━━━━━━━━━━━━━━ 14s 6ms/step - accuracy: 0.9952 - loss: 0.0121 - val_accuracy: 0.9964 - val_loss: 0.0485
# Epoch 16/250
# 2250/2250 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - accuracy: 0.9957 - loss: 0.0109 - val_accuracy: 0.9961 - val_loss: 0.0385
# Epoch 17/250
# 2250/2250 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - accuracy: 0.9953 - loss: 0.0110 - val_accuracy: 0.9958 - val_loss: 0.0556
# Epoch 18/250
# 2250/2250 ━━━━━━━━━━━━━━━━━━━━ 14s 6ms/step - accuracy: 0.9955 - loss: 0.0105 - val_accuracy: 0.9966 - val_loss: 0.0466
# Epoch 19/250
# 2250/2250 ━━━━━━━━━━━━━━━━━━━━ 14s 6ms/step - accuracy: 0.9955 - loss: 0.0117 - val_accuracy: 0.9966 - val_loss: 0.0707
# Epoch 20/250
# 2250/2250 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - accuracy: 0.9955 - loss: 0.0107 - val_accuracy: 0.9988 - val_loss: 0.0606
# Epoch 21/250
# 2250/2250 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - accuracy: 0.9959 - loss: 0.0098 - val_accuracy: 0.9939 - val_loss: 0.0858
# Epoch 22/250
# 2250/2250 ━━━━━━━━━━━━━━━━━━━━ 14s 6ms/step - accuracy: 0.9956 - loss: 0.0107 - val_accuracy: 0.9967 - val_loss: 0.0650
# Epoch 23/250
# 2250/2250 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - accuracy: 0.9964 - loss: 0.0095 - val_accuracy: 0.9981 - val_loss: 0.1141
# Epoch 24/250
# 2250/2250 ━━━━━━━━━━━━━━━━━━━━ 14s 6ms/step - accuracy: 0.9959 - loss: 0.0096 - val_accuracy: 0.9974 - val_loss: 0.1035
# Epoch 25/250
# 2250/2250 ━━━━━━━━━━━━━━━━━━━━ 14s 6ms/step - accuracy: 0.9960 - loss: 0.0094 - val_accuracy: 0.9977 - val_loss: 0.0981
# Epoch 26/250
# 2250/2250 ━━━━━━━━━━━━━━━━━━━━ 20s 6ms/step - accuracy: 0.9962 - loss: 0.0086 - val_accuracy: 0.9958 - val_loss: 0.0820
# Epoch 27/250
# 2250/2250 ━━━━━━━━━━━━━━━━━━━━ 14s 6ms/step - accuracy: 0.9963 - loss: 0.0101 - val_accuracy: 0.9967 - val_loss: 0.1197
# Epoch 28/250
# 2250/2250 ━━━━━━━━━━━━━━━━━━━━ 14s 6ms/step - accuracy: 0.9961 - loss: 0.0094 - val_accuracy: 0.9974 - val_loss: 0.0911
# Epoch 29/250
# 2250/2250 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - accuracy: 0.9965 - loss: 0.0089 - val_accuracy: 0.9968 - val_loss: 0.0925
# Epoch 30/250
# 2250/2250 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - accuracy: 0.9964 - loss: 0.0085 - val_accuracy: 0.9979 - val_loss: 0.0650
# Epoch 31/250
# 2250/2250 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - accuracy: 0.9962 - loss: 0.0093 - val_accuracy: 0.9959 - val_loss: 0.1131
# Epoch 32/250
# 2250/2250 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - accuracy: 0.9966 - loss: 0.0079 - val_accuracy: 0.9977 - val_loss: 0.0901
# Epoch 33/250
# 2250/2250 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - accuracy: 0.9963 - loss: 0.0088 - val_accuracy: 0.9974 - val_loss: 0.0876
# Epoch 34/250
# 2250/2250 ━━━━━━━━━━━━━━━━━━━━ 21s 6ms/step - accuracy: 0.9964 - loss: 0.0082 - val_accuracy: 0.9973 - val_loss: 0.1014
# Epoch 35/250
# 2250/2250 ━━━━━━━━━━━━━━━━━━━━ 14s 6ms/step - accuracy: 0.9968 - loss: 0.0079 - val_accuracy: 0.9981 - val_loss: 0.0544
# Epoch 36/250
# 2250/2250 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - accuracy: 0.9964 - loss: 0.0148 - val_accuracy: 0.9980 - val_loss: 0.1015
# Epoch 37/250
# 2250/2250 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - accuracy: 0.9968 - loss: 0.0077 - val_accuracy: 0.9978 - val_loss: 0.0757
# Epoch 38/250
# 2250/2250 ━━━━━━━━━━━━━━━━━━━━ 14s 6ms/step - accuracy: 0.9969 - loss: 0.0091 - val_accuracy: 0.9964 - val_loss: 0.1287
# Epoch 39/250
# 2250/2250 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - accuracy: 0.9968 - loss: 0.0081 - val_accuracy: 0.9970 - val_loss: 0.1045
# Epoch 40/250
# 2250/2250 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - accuracy: 0.9968 - loss: 0.0078 - val_accuracy: 0.9974 - val_loss: 0.0997
# Epoch 41/250
# 2250/2250 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - accuracy: 0.9968 - loss: 0.0080 - val_accuracy: 0.9980 - val_loss: 0.0770
# Epoch 42/250
# 2250/2250 ━━━━━━━━━━━━━━━━━━━━ 20s 6ms/step - accuracy: 0.9967 - loss: 0.0078 - val_accuracy: 0.9982 - val_loss: 0.0764
# Epoch 43/250
# 2250/2250 ━━━━━━━━━━━━━━━━━━━━ 14s 6ms/step - accuracy: 0.9964 - loss: 0.0081 - val_accuracy: 0.9982 - val_loss: 0.0693
# Epoch 44/250
# 2250/2250 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - accuracy: 0.9969 - loss: 0.0084 - val_accuracy: 0.9977 - val_loss: 0.0911
# Epoch 45/250
# 2250/2250 ━━━━━━━━━━━━━━━━━━━━ 14s 6ms/step - accuracy: 0.9968 - loss: 0.0073 - val_accuracy: 0.9972 - val_loss: 0.0841
# Epoch 46/250
# 2250/2250 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - accuracy: 0.9968 - loss: 0.0072 - val_accuracy: 0.9981 - val_loss: 0.0835
# Epoch 47/250
# 2250/2250 ━━━━━━━━━━━━━━━━━━━━ 21s 6ms/step - accuracy: 0.9967 - loss: 0.0076 - val_accuracy: 0.9977 - val_loss: 0.0778
# Epoch 48/250
# 2250/2250 ━━━━━━━━━━━━━━━━━━━━ 14s 6ms/step - accuracy: 0.9966 - loss: 0.0087 - val_accuracy: 0.9978 - val_loss: 0.0995
# Epoch 49/250
# 2250/2250 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - accuracy: 0.9969 - loss: 0.0073 - val_accuracy: 0.9982 - val_loss: 0.1032
# Epoch 50/250
# 2250/2250 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - accuracy: 0.9966 - loss: 0.0078 - val_accuracy: 0.9977 - val_loss: 0.0721
# Epoch 51/250
# 2250/2250 ━━━━━━━━━━━━━━━━━━━━ 20s 6ms/step - accuracy: 0.9969 - loss: 0.0089 - val_accuracy: 0.9974 - val_loss: 0.1429
# Epoch 52/250
# 2250/2250 ━━━━━━━━━━━━━━━━━━━━ 14s 6ms/step - accuracy: 0.9972 - loss: 0.0065 - val_accuracy: 0.9975 - val_loss: 0.1196
# Epoch 53/250
# 2250/2250 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - accuracy: 0.9971 - loss: 0.0069 - val_accuracy: 0.9973 - val_loss: 0.1264
# Epoch 54/250
# 2250/2250 ━━━━━━━━━━━━━━━━━━━━ 14s 6ms/step - accuracy: 0.9972 - loss: 0.0066 - val_accuracy: 0.9983 - val_loss: 0.0956
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9940 - loss: 0.0138
# Acurácia nos dados de teste: 0.9939749836921692
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# F1-Score do modelo: 0.9934839623932501

# %%
import tensorflow as tf
from tensorflow import keras
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import f1_score
import numpy as np
from keras.optimizers import Nadam

# Separar recursos (X) e rótulos (y)
X1 = features
y1 = actions

# Normalizar os recursos (importante para redes neurais)
scaler1 = StandardScaler()
X1 = scaler1.fit_transform(X1)

# Divida seus dados em conjuntos de treinamento e teste
X_train, X_test, y_train, y_test = train_test_split(X1, y1, test_size=0.2, random_state=42)

nadam = Nadam(learning_rate=0.002, beta_1=0.9, beta_2=0.999)

model = keras.Sequential([
    keras.layers.Dense(160, activation='relu', input_shape=(X_train.shape[1],)),
    keras.layers.Dropout(0.2),
    keras.layers.Dense(320, activation='relu'),
    keras.layers.Dropout(0.2),
    keras.layers.Dense(480, activation='relu'),
    keras.layers.Dense(640, activation='softmax')
])

early_stopping = keras.callbacks.EarlyStopping(patience=50, restore_best_weights=True)

# Experimente diferentes funções de ativação, taxa de aprendizado e otimizador
model.compile(optimizer=nadam, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Aumente o número de épocas
model.fit(X_train, y_train, epochs=250, batch_size=160, validation_split=0.001, callbacks=[early_stopping])

test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f'Acurácia nos dados de teste: {test_accuracy}')

# Fazer previsões
predictions = model.predict(X_test)

# Arredondar as previsões para obter rótulos de classe
predicted_labels = np.argmax(predictions, axis=1)

# Calcular o F1-Score
f1 = f1_score(y_test, predicted_labels, average='weighted')

print(f'F1-Score do modelo: {f1}')
# Out:
# Epoch 1/250
# 999/999 ━━━━━━━━━━━━━━━━━━━━ 34s 31ms/step - accuracy: 0.9748 - loss: 0.2187 - val_accuracy: 0.9937 - val_loss: 0.0136
# Epoch 2/250
# 999/999 ━━━━━━━━━━━━━━━━━━━━ 30s 30ms/step - accuracy: 0.9897 - loss: 0.0273 - val_accuracy: 0.9937 - val_loss: 0.0122
# Epoch 3/250
# 999/999 ━━━━━━━━━━━━━━━━━━━━ 41s 30ms/step - accuracy: 0.9915 - loss: 0.0218 - val_accuracy: 0.9937 - val_loss: 0.0120
# Epoch 4/250
# 999/999 ━━━━━━━━━━━━━━━━━━━━ 30s 30ms/step - accuracy: 0.9925 - loss: 0.0190 - val_accuracy: 0.9937 - val_loss: 0.0119
# Epoch 5/250
# 999/999 ━━━━━━━━━━━━━━━━━━━━ 41s 30ms/step - accuracy: 0.9933 - loss: 0.0175 - val_accuracy: 0.9937 - val_loss: 0.0077
# Epoch 6/250
# 999/999 ━━━━━━━━━━━━━━━━━━━━ 41s 30ms/step - accuracy: 0.9939 - loss: 0.0163 - val_accuracy: 0.9937 - val_loss: 0.0158
# Epoch 7/250
# 999/999 ━━━━━━━━━━━━━━━━━━━━ 41s 30ms/step - accuracy: 0.9940 - loss: 0.0223 - val_accuracy: 0.9937 - val_loss: 0.0075
# Epoch 8/250
# 999/999 ━━━━━━━━━━━━━━━━━━━━ 41s 30ms/step - accuracy: 0.9943 - loss: 0.0145 - val_accuracy: 0.9937 - val_loss: 0.0082
# Epoch 9/250
# 999/999 ━━━━━━━━━━━━━━━━━━━━ 41s 30ms/step - accuracy: 0.9950 - loss: 0.0130 - val_accuracy: 0.9937 - val_loss: 0.0107
# Epoch 10/250
# 999/999 ━━━━━━━━━━━━━━━━━━━━ 41s 30ms/step - accuracy: 0.9952 - loss: 0.0126 - val_accuracy: 0.9937 - val_loss: 0.0079
# Epoch 11/250
# 999/999 ━━━━━━━━━━━━━━━━━━━━ 42s 31ms/step - accuracy: 0.9951 - loss: 0.0125 - val_accuracy: 0.9937 - val_loss: 0.0085
# Epoch 12/250
# 999/999 ━━━━━━━━━━━━━━━━━━━━ 30s 30ms/step - accuracy: 0.9947 - loss: 0.0125 - val_accuracy: 1.0000 - val_loss: 0.0032
# Epoch 13/250
# 999/999 ━━━━━━━━━━━━━━━━━━━━ 30s 30ms/step - accuracy: 0.9951 - loss: 0.0122 - val_accuracy: 0.9937 - val_loss: 0.0096
# Epoch 14/250
# 999/999 ━━━━━━━━━━━━━━━━━━━━ 41s 30ms/step - accuracy: 0.9953 - loss: 0.0133 - val_accuracy: 0.9937 - val_loss: 0.0183
# Epoch 15/250
# 999/999 ━━━━━━━━━━━━━━━━━━━━ 41s 30ms/step - accuracy: 0.9957 - loss: 0.0108 - val_accuracy: 0.9937 - val_loss: 0.0088
# Epoch 16/250
# 999/999 ━━━━━━━━━━━━━━━━━━━━ 42s 31ms/step - accuracy: 0.9953 - loss: 0.0122 - val_accuracy: 0.9937 - val_loss: 0.0078
# Epoch 17/250
# 999/999 ━━━━━━━━━━━━━━━━━━━━ 43s 33ms/step - accuracy: 0.9956 - loss: 0.0114 - val_accuracy: 0.9937 - val_loss: 0.0081
# Epoch 18/250
# 999/999 ━━━━━━━━━━━━━━━━━━━━ 32s 32ms/step - accuracy: 0.9957 - loss: 0.0104 - val_accuracy: 0.9937 - val_loss: 0.0072
# Epoch 19/250
# 999/999 ━━━━━━━━━━━━━━━━━━━━ 39s 30ms/step - accuracy: 0.9960 - loss: 0.0092 - val_accuracy: 0.9937 - val_loss: 0.0102
# Epoch 20/250
# 999/999 ━━━━━━━━━━━━━━━━━━━━ 29s 29ms/step - accuracy: 0.9961 - loss: 0.0108 - val_accuracy: 1.0000 - val_loss: 0.0045
# Epoch 21/250
# 999/999 ━━━━━━━━━━━━━━━━━━━━ 47s 35ms/step - accuracy: 0.9958 - loss: 0.0100 - val_accuracy: 1.0000 - val_loss: 0.0052
# Epoch 22/250
# 999/999 ━━━━━━━━━━━━━━━━━━━━ 40s 34ms/step - accuracy: 0.9957 - loss: 0.0118 - val_accuracy: 1.0000 - val_loss: 0.0077
# Epoch 23/250
# 999/999 ━━━━━━━━━━━━━━━━━━━━ 42s 34ms/step - accuracy: 0.9964 - loss: 0.0094 - val_accuracy: 0.9937 - val_loss: 0.0062
# Epoch 24/250
# 999/999 ━━━━━━━━━━━━━━━━━━━━ 40s 40ms/step - accuracy: 0.9964 - loss: 0.0112 - val_accuracy: 0.9937 - val_loss: 0.0069
# Epoch 25/250
# 999/999 ━━━━━━━━━━━━━━━━━━━━ 31s 30ms/step - accuracy: 0.9962 - loss: 0.0094 - val_accuracy: 1.0000 - val_loss: 0.0058
# Epoch 26/250
# 999/999 ━━━━━━━━━━━━━━━━━━━━ 40s 30ms/step - accuracy: 0.9967 - loss: 0.0089 - val_accuracy: 1.0000 - val_loss: 0.0048
# Epoch 27/250
# 999/999 ━━━━━━━━━━━━━━━━━━━━ 32s 32ms/step - accuracy: 0.9962 - loss: 0.0094 - val_accuracy: 0.9937 - val_loss: 0.0087
# Epoch 28/250
# 999/999 ━━━━━━━━━━━━━━━━━━━━ 39s 30ms/step - accuracy: 0.9963 - loss: 0.0101 - val_accuracy: 1.0000 - val_loss: 0.0020
# Epoch 29/250
# 999/999 ━━━━━━━━━━━━━━━━━━━━ 42s 31ms/step - accuracy: 0.9965 - loss: 0.0090 - val_accuracy: 1.0000 - val_loss: 0.0054
# Epoch 30/250
# 999/999 ━━━━━━━━━━━━━━━━━━━━ 35s 35ms/step - accuracy: 0.9965 - loss: 0.0089 - val_accuracy: 1.0000 - val_loss: 0.0035
# Epoch 31/250
# 999/999 ━━━━━━━━━━━━━━━━━━━━ 42s 35ms/step - accuracy: 0.9967 - loss: 0.0090 - val_accuracy: 0.9937 - val_loss: 0.0073
# Epoch 32/250
# 999/999 ━━━━━━━━━━━━━━━━━━━━ 36s 31ms/step - accuracy: 0.9964 - loss: 0.0091 - val_accuracy: 0.9937 - val_loss: 0.0139
# Epoch 33/250
# 999/999 ━━━━━━━━━━━━━━━━━━━━ 39s 39ms/step - accuracy: 0.9966 - loss: 0.0083 - val_accuracy: 0.9937 - val_loss: 0.0073
# Epoch 34/250
# 999/999 ━━━━━━━━━━━━━━━━━━━━ 37s 34ms/step - accuracy: 0.9969 - loss: 0.0078 - val_accuracy: 0.9937 - val_loss: 0.0071
# Epoch 35/250
# 999/999 ━━━━━━━━━━━━━━━━━━━━ 51s 44ms/step - accuracy: 0.9963 - loss: 0.0092 - val_accuracy: 1.0000 - val_loss: 0.0040
# Epoch 36/250
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 37
#      34 model.compile(optimizer=nadam, loss='sparse_categorical_crossentropy', metrics=['accuracy'])
#      36 # Aumente o número de épocas
# ---> 37 model.fit(X_train, y_train, epochs=250, batch_size=160, validation_split=0.001, callbacks=[early_stopping])
#      39 test_loss, test_accuracy = model.evaluate(X_test, y_test)
#      40 print(f'Acurácia nos dados de teste: {test_accuracy}')
#
# File ~/Documentos/Out/venv/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/Documentos/Out/venv/lib/python3.10/site-packages/keras/src/backend/tensorflow/trainer.py:313, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     311 with epoch_iterator.catch_stop_iteration():
#     312     for step, iterator in epoch_iterator.enumerate_epoch():
# --> 313         callbacks.on_train_batch_begin(step)
#     314         logs = self.train_function(iterator)
#     315         logs = self._pythonify_logs(logs)
#
# File ~/Documentos/Out/venv/lib/python3.10/site-packages/keras/src/callbacks/callback_list.py:98, in CallbackList.on_train_batch_begin(self, batch, logs)
#      95     for callback in self.callbacks:
#      96         callback.on_epoch_end(epoch, logs)
# ---> 98 def on_train_batch_begin(self, batch, logs=None):
#      99     logs = logs or {}
#     100     for callback in self.callbacks:
#
# KeyboardInterrupt:
