# %%
# !python3 --version
# Out:
# Python 3.8.16

# %%
# !pip install edward2
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 163 kB 24.6 MB/s
# ...

# %%
import edward2 as ed
import tensorflow as tf

norma_rv = ed.Normal(loc = tf.zeros(2), scale=tf.ones(2))

print(norma_rv)
# Out:
# RandomVariable("[ 0.8314895 -1.7428945]", shape=(2,), dtype=float32, device=/job:localhost/replica:0/task:0/device:CPU:0)
